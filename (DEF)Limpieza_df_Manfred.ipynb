# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_csv("extraccion_manfred_final.csv") #DataFrame Manfred (MILA)

# %%
df2.head()
# Out:
#                                                  url       nombre  \
# 0  https://www.getmanfred.com/ofertas-empleo/7684...    SuperReal
# 1  https://www.getmanfred.com/ofertas-empleo/7648...      Sngular
# 2  https://www.getmanfred.com/ofertas-empleo/7546...    Idealista
# 3  https://www.getmanfred.com/ofertas-empleo/7511...  Valar Space
# 4  https://www.getmanfred.com/ofertas-empleo/7406...   MavelPoint
#
#                       oferta  fecha     salario  remoto localizacion  \
# 0         Tech Lead (Nodejs)  abr25     €50-60K   False       Madrid
# 1     JS Fullstack Developer  abr25     €35-42K    True          NaN
# 2        UX Product Designer  abr25  Hasta €55K   False       Madrid
# 3     Java Backend Developer  mar25     €35-40K    True          NaN
# 4  Senior Frontend Developer  mar25  Hasta €55K    True          NaN
#
#   teletrabajo     dia_laborable vacaciones  \
# 0         20%  Jornada completa    25 días
# 1        100%  Jornada completa    25 días
# 2         60%  Jornada completa    23 días
# 3        100%  Jornada completa    22 días
# 4        100%  Jornada completa    23 días
#
#                                          Tecnologías  \
# 0          ['NodeJS', 'REST', 'TypeScript', 'Azure']
# 1  ['NodeJS', 'REST', 'MongoDB', 'SQL', 'React', ...
# 2                                          ['Figma']
# 3  ['Java', 'Spring', 'Hibernate', 'Github', 'API...
# 4  ['NextJS', 'React', 'PostgreSQL', 'Azure', 'ne...
#
#                                    Otras habilidades                Idiomas  \
# 0  ['Trabajo en equipo', 'Pensamiento analítico',...             ['Inglés']
# 1  ['Adaptabilidad al cambio', 'Trabajo en equipo...             ['Inglés']
# 2  ['Visión crítica', 'Capacidad de abstracción',...             ['Inglés']
# 3  ['Atención al detalle', 'Capacidad de dar feed...  ['Español', 'Inglés']
# 4  ['Aprendizaje Continuo', 'Capacidad de dar fee...                    NaN
#
#                                               textos  \
# 0  ¿Cómo lo harás?SuperReal tiene el tamaño de un...
# 1  ¿Cómo lo harás?Déjame que te describa la quint...
# 2  ¿Cómo lo harás?Es una organización muy plana, ...
# 3  ¿Cómo lo harás?Tu día empezará revisando Linea...
# 4  ¿Cómo lo harás?Como decíamos más arriba, nos e...
#
#                                           Beneficios
# 0                                                NaN
# 1  ['Clases de Idiomas', 'Posibilidad de elegir e...
# 2  ['Clases de Idiomas', 'Café, fruta y snacks', ...
# 3  ['Cheque Guardería', 'Presupuesto para formaci...
# 4                     ['Presupuesto para formación']

# %%
#poner el nombre de las columnas en minúscula
df2.columns = df2.columns.str.lower()

# %%
#renombrar las columnas para unir los dataframes
df2.rename(columns={"url": "id_urls",
                    "nombre": "empresa",
                    "remoto": "modalidad",
                    "localizacion": "ubicacion",
                    "teletrabajo": "modalidad_2",
                    "dia_laborable": "jornada",
                    "tecnologías": "tecnologias_aptitudes",
                    "otras habilidades": "skills",
                    "textos": "descripcion"
                    }
           , inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1279 entries, 0 to 1278
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_urls                1279 non-null   object
#  1   empresa                1279 non-null   object
#  2   oferta                 1279 non-null   object
#  3   fecha                  1279 non-null   object
#  4   salario                1279 non-null   object
#  5   modalidad              1279 non-null   bool
#  6   ubicacion              265 non-null    object
#  7   modalidad_2            1250 non-null   object
#  8   jornada                1033 non-null   object
#  9   vacaciones             1277 non-null   object
#  10  tecnologias_aptitudes  1180 non-null   object
#  11  skills                 1169 non-null   object
#  12  idiomas                293 non-null    object
#  13  descripcion            1279 non-null   object
#  14  beneficios             1090 non-null   object
# dtypes: bool(1), object(14)
# memory usage: 141.3+ KB

# %% [markdown]
# #### PORTAL_EMPLEO

# %%
#añadimos la columna "portal_empleo" a partir de la columna "id_urls"
df2["portal_empleo"] = df2["id_urls"].str.split("www.").str[1].str.split(".com").str[0]
#Reemplazar NaN por None
df2["portal_empleo"] = df2["portal_empleo"].replace({pd.NA: None, np.nan: None})

# %% [markdown]
# #### EMPRESA

# %%
df2["empresa"] = df2["empresa"].replace({pd.NA: None, np.nan: None})

# %% [markdown]
# #### OFERTA

# %%
df2["oferta"] = df2["oferta"].replace({pd.NA: None, np.nan: None})

# %% [markdown]
# #### FECHA

# %%
df2["fecha"].value_counts()
# Out:
# fecha
# may22        49
# mar23        45
# mar22        45
# ene23        45
# nov22        40
# sept22       39
# mar24        37
# jun21        37
# oct22        36
# mar25        34
# jul23        34
# ene24        33
# feb23        32
# abr22        32
# may23        31
# dic22        30
# jun22        29
# feb24        27
# abr24        27
# oct23        26
# feb22        26
# ene22        26
# oct24        26
# jun23        26
# abr23        26
# sept21       25
# feb25        25
# ene25        25
# jul24        25
# dic21        24
# sept23       24
# ago22        23
# jul22        23
# nov23        22
# nov21        21
# sept24       20
# nov24        20
# ago23        20
# oct21        20
# may24        20
# jun24        17
# dic24        14
# ago21        14
# abr25        13
# dic23        12
# jul21        12
# ago24        12
# en            4
# developer     3
# 24            1
# manager       1
# engineer      1
# Name: count, dtype: int64

# %%
df2["fecha"].unique()
# Out:
# array(['abr25', 'mar25', 'feb25', 'ene25', 'dic24', 'nov24', 'oct24',
#        'sept24', 'ago24', 'jul24', 'jun24', 'may24', 'abr24', 'mar24',
#        'feb24', 'oct23', '24', 'ene24', 'dic23', 'nov23', 'sept23',
#        'jul23', 'ago23', 'jun23', 'may23', 'abr23', 'mar23', 'feb23',
#        'ene23', 'nov22', 'dic22', 'oct22', 'ago22', 'sept22', 'jul22',
#        'jun22', 'may22', 'abr22', 'mar22', 'en', 'feb22', 'ene22',
#        'dic21', 'nov21', 'oct21', 'developer', 'sept21', 'ago21', 'jul21',
#        'jun21', 'manager', 'engineer'], dtype=object)

# %%
meses = {
    "ene": "01", "feb": "02", "mar": "03", "abr": "04", "may": "05", "jun": "06",
    "jul": "07", "ago": "08", "sept": "09", "oct": "10", "nov": "11", "dic": "12"
}

# %%
def convertir_fecha(fecha):
    if isinstance(fecha, str):
        if len(fecha) == 5:
            mes_abr = fecha[:3].lower()
        elif len(fecha) == 6:
            mes_abr = fecha[:4].lower()
        else:
            return None
        
        anio = "20" + fecha[-2:]
        mes = meses.get(mes_abr)
        if mes:
            return f"{mes}/{anio}"
    return None

# %%
df2["fecha"] = df2["fecha"].apply(convertir_fecha)

# %%
df2["fecha"] = pd.to_datetime(df2["fecha"], format="%m/%Y", errors="coerce")
df2["fecha"] = df2["fecha"].replace({pd.NaT: None})

# %%
df2.head()
# Out:
#                                              id_urls      empresa  \
# 0  https://www.getmanfred.com/ofertas-empleo/7684...    SuperReal
# 1  https://www.getmanfred.com/ofertas-empleo/7648...      Sngular
# 2  https://www.getmanfred.com/ofertas-empleo/7546...    Idealista
# 3  https://www.getmanfred.com/ofertas-empleo/7511...  Valar Space
# 4  https://www.getmanfred.com/ofertas-empleo/7406...   MavelPoint
#
#                       oferta                fecha     salario  modalidad  \
# 0         Tech Lead (Nodejs)  2025-04-01 00:00:00     €50-60K      False
# 1     JS Fullstack Developer  2025-04-01 00:00:00     €35-42K       True
# 2        UX Product Designer  2025-04-01 00:00:00  Hasta €55K      False
# 3     Java Backend Developer  2025-03-01 00:00:00     €35-40K       True
# 4  Senior Frontend Developer  2025-03-01 00:00:00  Hasta €55K       True
#
#   ubicacion modalidad_2           jornada vacaciones  \
# 0    Madrid         20%  Jornada completa    25 días
# 1       NaN        100%  Jornada completa    25 días
# 2    Madrid         60%  Jornada completa    23 días
# 3       NaN        100%  Jornada completa    22 días
# 4       NaN        100%  Jornada completa    23 días
#
#                                tecnologias_aptitudes  \
# 0          ['NodeJS', 'REST', 'TypeScript', 'Azure']
# 1  ['NodeJS', 'REST', 'MongoDB', 'SQL', 'React', ...
# 2                                          ['Figma']
# 3  ['Java', 'Spring', 'Hibernate', 'Github', 'API...
# 4  ['NextJS', 'React', 'PostgreSQL', 'Azure', 'ne...
#
#                                               skills                idiomas  \
# 0  ['Trabajo en equipo', 'Pensamiento analítico',...             ['Inglés']
# 1  ['Adaptabilidad al cambio', 'Trabajo en equipo...             ['Inglés']
# 2  ['Visión crítica', 'Capacidad de abstracción',...             ['Inglés']
# 3  ['Atención al detalle', 'Capacidad de dar feed...  ['Español', 'Inglés']
# 4  ['Aprendizaje Continuo', 'Capacidad de dar fee...                    NaN
#
#                                          descripcion  \
# 0  ¿Cómo lo harás?SuperReal tiene el tamaño de un...
# 1  ¿Cómo lo harás?Déjame que te describa la quint...
# 2  ¿Cómo lo harás?Es una organización muy plana, ...
# 3  ¿Cómo lo harás?Tu día empezará revisando Linea...
# 4  ¿Cómo lo harás?Como decíamos más arriba, nos e...
#
#                                           beneficios portal_empleo
# 0                                                NaN    getmanfred
# 1  ['Clases de Idiomas', 'Posibilidad de elegir e...    getmanfred
# 2  ['Clases de Idiomas', 'Café, fruta y snacks', ...    getmanfred
# 3  ['Cheque Guardería', 'Presupuesto para formaci...    getmanfred
# 4                     ['Presupuesto para formación']    getmanfred

# %% [markdown]
# #### SALARIO

# %%
def limpiar_salario(salario):
    salario = str(salario).replace("€", "").replace("US$", "").replace("£", "").replace(",", "").replace("K", "").replace("Hasta", "").replace("Desde", "").replace("/hora", "").replace("MXN$", "").strip()

    if '-' in salario:
        salario_min, salario_max = salario.split('-')
        return pd.Series([float(salario_min)*1000, float(salario_max)*1000])
    else:
        return pd.Series([float(salario)*1000, float(salario)*1000])

# %%
df2[['salario_min', 'salario_max']] = df2['salario'].apply(limpiar_salario)

# %%
df2.drop(columns = "salario", inplace = True)

# %%
df2.head()
# Out:
#                                              id_urls      empresa  \
# 0  https://www.getmanfred.com/ofertas-empleo/7684...    SuperReal
# 1  https://www.getmanfred.com/ofertas-empleo/7648...      Sngular
# 2  https://www.getmanfred.com/ofertas-empleo/7546...    Idealista
# 3  https://www.getmanfred.com/ofertas-empleo/7511...  Valar Space
# 4  https://www.getmanfred.com/ofertas-empleo/7406...   MavelPoint
#
#                       oferta                fecha  modalidad ubicacion  \
# 0         Tech Lead (Nodejs)  2025-04-01 00:00:00      False    Madrid
# 1     JS Fullstack Developer  2025-04-01 00:00:00       True       NaN
# 2        UX Product Designer  2025-04-01 00:00:00      False    Madrid
# 3     Java Backend Developer  2025-03-01 00:00:00       True       NaN
# 4  Senior Frontend Developer  2025-03-01 00:00:00       True       NaN
#
#   modalidad_2           jornada vacaciones  \
# 0         20%  Jornada completa    25 días
# 1        100%  Jornada completa    25 días
# 2         60%  Jornada completa    23 días
# 3        100%  Jornada completa    22 días
# 4        100%  Jornada completa    23 días
#
#                                tecnologias_aptitudes  \
# 0          ['NodeJS', 'REST', 'TypeScript', 'Azure']
# 1  ['NodeJS', 'REST', 'MongoDB', 'SQL', 'React', ...
# 2                                          ['Figma']
# 3  ['Java', 'Spring', 'Hibernate', 'Github', 'API...
# 4  ['NextJS', 'React', 'PostgreSQL', 'Azure', 'ne...
#
#                                               skills                idiomas  \
# 0  ['Trabajo en equipo', 'Pensamiento analítico',...             ['Inglés']
# 1  ['Adaptabilidad al cambio', 'Trabajo en equipo...             ['Inglés']
# 2  ['Visión crítica', 'Capacidad de abstracción',...             ['Inglés']
# 3  ['Atención al detalle', 'Capacidad de dar feed...  ['Español', 'Inglés']
# 4  ['Aprendizaje Continuo', 'Capacidad de dar fee...                    NaN
#
#                                          descripcion  \
# 0  ¿Cómo lo harás?SuperReal tiene el tamaño de un...
# 1  ¿Cómo lo harás?Déjame que te describa la quint...
# 2  ¿Cómo lo harás?Es una organización muy plana, ...
# 3  ¿Cómo lo harás?Tu día empezará revisando Linea...
# 4  ¿Cómo lo harás?Como decíamos más arriba, nos e...
#
#                                           beneficios portal_empleo  \
# 0                                                NaN    getmanfred
# 1  ['Clases de Idiomas', 'Posibilidad de elegir e...    getmanfred
# 2  ['Clases de Idiomas', 'Café, fruta y snacks', ...    getmanfred
# 3  ['Cheque Guardería', 'Presupuesto para formaci...    getmanfred
# 4                     ['Presupuesto para formación']    getmanfred
#
#    salario_min  salario_max
# 0      50000.0      60000.0
# 1      35000.0      42000.0
# 2      55000.0      55000.0
# 3      35000.0      40000.0
# 4      55000.0      55000.0

# %% [markdown]
# #### MODALIDAD

# %%
df2["modalidad_2"].unique()
# Out:
# array(['20%', '100%', '60%', nan, '40%', '50%', '70%', '90%', '80%',
#        '30%', '75%', '25%', '95%'], dtype=object)

# %%
#def columna_modalidad(valor):
df2['modalidad'] = df2['modalidad'].apply(lambda x: "Teletrabajo" if x == True else ("Teletrabajo" if df2['modalidad_2'][x.name] == 100 
          else "Híbrido"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/44/yxyhc5dn6yvcxpkdphszv5040000gn/T/ipykernel_90241/241287256.py in ?()
#       1 #def columna_modalidad(valor):
# ----> 2 if df2["modalidad"] == True:
#       3     df2["modalidad"] == "Teletrabajo"
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# #### UBICACION

# %%
df2["ubicacion"].unique()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# array(['Madrid', nan, 'Sevilla', 'Barcelona', 'A Coruña',
#        'Bergondo o A Coruña', 'Valencia', 'Vigo', 'Zaragoza o Madrid',
#        'Gijón', 'Bilbao o Madrid o Sevilla', 'Oviedo',
#        'Madrid o Valencia', 'Madrid o Valencia o Sevilla',
#        'Madrid o Sevilla o Palma', 'Madrid o A Coruña', 'Logroño',
#        'Bilbao', 'Málaga', 'A Coruña o Madrid', 'Alcobendas',
#        'Valencia o Madrid', 'Santander', 'Zaragoza', 'Madrid o Zaragoza',
#        'San Sebastián', 'Madrid o Málaga', 'Palma o Barcelona'],
#       dtype=object)

# %% [markdown]
# #### JORNADA

# %%
df2["jornada"].unique()
# Out:
# array(['Jornada completa', nan], dtype=object)

# %% [markdown]
# #### VACACIONES

# %%
df2["vacaciones"].unique()
# Out:
# array(['25 días', '23 días', '22 días', '26 días', 'Ilimitado', nan,
#        '24 días', '30 días', '27 días', '21 días', '34 días', '28 días',
#        '35 días', '29 días', '40 días', '31 días', '36 días', '10 días',
#        '33 días'], dtype=object)

# %%
def limpiar_vacaciones(valor):
    if pd.isna(valor):
        return None
    else:
        return valor.split()[0]

df2["vacaciones"] = df2["vacaciones"].apply(limpiar_vacaciones)

# %%
df2["vacaciones_sin_ilimitado"] = df2["vacaciones"].apply(lambda x: np.nan if x == "Ilimitado" else x)
media_vacaciones = df2["vacaciones_sin_ilimitado"].mean()
df2["vacaciones"] = df2["vacaciones"].apply(lambda x: media_vacaciones if x == "Ilimitado" else x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 2
#       1 df2["vacaciones_sin_ilimitado"] = df2["vacaciones"].apply(lambda x: np.nan if x == "Ilimitado" else x)
# ----> 2 media_vacaciones = df2["vacaciones_sin_ilimitado"].mean()
#       3 df2["vacaciones"] = df2["vacaciones"].apply(lambda x: media_vacaciones if x == "Ilimitado" else x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
def media_ilimitado(valor):
    media_vacaciones = df2["vacaciones_sin_ilimitado"].mean()
    if "Ilimitado" in valor:
        return df2["vacaciones"].mean()

df2["vacaciones"] = df2["vacaciones"].apply(media_ilimitado)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 5
#       2     if "Ilimitado" in valor:
#       3         return df2["vacaciones"].mean()
# ----> 5 df2["vacaciones"] = df2["vacaciones"].apply(media_ilimitado)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[70], line 3, in media_ilimitado(valor)
#       1 def media_ilimitado(valor):
#       2     if "Ilimitado" in valor:
# ----> 3         return df2["vacaciones"].mean()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
df2["vacaciones"].unique()
# Out:
# array(['25', '23', '22', '26', 'Ilimitado', None, '24', '30', '27', '21',
#        '34', '28', '35', '29', '40', '31', '36', '10', '33'], dtype=object)

# %% [markdown]
# #### TECNOLOGIAS_APTITUDES

# %%
df2["tecnologias_aptitudes"].unique()
# Out:
# array(["['NodeJS', 'REST', 'TypeScript', 'Azure']",
#        "['NodeJS', 'REST', 'MongoDB', 'SQL', 'React', 'TypeScript', 'Docker', 'AWS']",
#        "['Figma']",
#        "['Java', 'Spring', 'Hibernate', 'Github', 'API', 'AWS', 'MySQL', 'HTML', 'CSS']",
#        "['NextJS', 'React', 'PostgreSQL', 'Azure', 'nestJS']",
#        "['Java', 'SQL', 'SOAP', 'OpenApi', 'JavaScript', 'C++', 'Cobol']",
#        "['PHP', 'Laravel']", "['Python', 'SQL', 'Kibana', 'Grafana']",
#        "['Java', 'Kafka', 'JUnit', 'SQL', 'Bash', 'AWS', 'Google Cloud', 'Azure']",
#        nan,
#        "['AWS', 'Airflow', 'Python', 'Google Cloud', 'Azure', 'Spark', 'Grafana']",
#        "['Spring Boot', 'Java', 'Azure', 'JUnit', 'Cucumber']",
#        "['Java', 'Linux', 'MongoDB', 'MySQL', 'AWS', 'Docker', 'Python', '.NET', 'NodeJS', 'Scala', 'Spark']",
#        "['AWS', 'Docker', 'PostgreSQL', 'Kubernetes', 'React', 'Ruby on Rails', 'Redshift', 'Elixir', 'TypeScript', 'NextJS', 'Go', 'Scala']",
#        "['Java', 'SQL', 'Spring']", "['Linux', 'AWS EC2', 'Plesk']",
#        "['JavaScript', 'HTML', 'CSS', 'Python', 'Elixir', 'Ruby', 'PHP', 'AWS', 'MySQL', 'PostgreSQL']",
#        "['Python', 'Django', 'Git', 'Bootstrap', 'Vue', 'Pytest', 'AWS', 'Github']",
#        "['.NET', 'C#', 'SQL', 'JavaScript', 'Azure', 'Azure DevOps']",
#        "['.NET', 'Angular2+', 'Azure', '.Net Core', 'Docker', 'Kubernetes']",
#        "['Zoho', 'Trello', 'Canva', 'ChatGPT', 'Jira']",
#        "['Linux', 'Microsoft', 'Docker', 'Proxmox']",
#        "['Java', 'Spring', 'Spring Boot', 'HTML', 'JavaScript', 'CSS', 'MySQL', 'Struts', 'React', 'JSP', 'Elasticsearch']",
#        "['AWS', 'Linux', 'GitHub Actions', 'Kubernetes', 'Jenkins', 'Terraform', 'Bash', 'Go', 'Python']",
#        "['Java', 'Spring', 'AWS', 'React', 'JavaScript', 'Kotlin', 'GraphQL']",
#        "['BigCommerce', 'Salesforce', 'Shopify', 'WooCommerce', 'Magento', 'Prestashop']",
#        "['Magento', 'Prestashop', 'BigCommerce', 'Salesforce', 'Shopify', 'WooCommerce']",
#        "['Scala', 'Python', 'RabbitMQ', 'Kafka', 'Java', 'Go', 'MySQL', 'MongoDB']",
#        "['React', 'HTML', 'CSS', 'Figma']",
#        "['PHP', 'Symfony', 'MySQL', 'API']",
#        "['Spring Boot', 'Java', 'ETL', 'Python']",
#        "['.NET', 'SQL', 'Git', 'API', 'Angular2+', 'XML', 'JSON']",
#        "['CRM', 'Notion', 'Jira']",
#        "['HTML', 'CSS', 'JavaScript', 'TypeScript', 'Git', 'React', 'Vue', 'Jest', 'Astro', 'Figma', 'Storybook']",
#        "['JavaScript', 'CSS', 'HTML', 'MySQL', 'PHP']",
#        "['JavaScript', 'TypeScript', 'React', 'HTML', 'CSS', 'Scss', 'AWS', 'Fastapi']",
#        "['Prestashop', 'JavaScript', 'Vue', 'Angular2+', 'React', 'BigCommerce', 'Figma', 'Tailwind']",
#        "['SQL', 'PostgreSQL', 'Python', 'AWS', 'Django', 'Celery', 'Terraform']",
#        "['Python', 'PostgreSQL', 'AWS', 'Git', 'Fastapi']",
#        "['Microsoft Excel', 'Google Sheets', 'SQL']",
#        "['SQL', 'dbt', 'Python', 'Google Cloud', 'Airflow', 'Docker']",
#        "['Kotlin', 'Swift']",
#        "['.NET', 'AWS', 'RabbitMQ', 'Python', 'Docker', 'GitLab']",
#        "['Java', 'Spring', 'Kafka', 'Azure', 'Kubernetes', 'Terraform', 'Docker']",
#        "['Java', 'Spring Boot', 'Kafka', 'React', 'JavaScript', 'Azure', 'AWS']",
#        "['SQL', 'AWS', 'Docker', 'PostgreSQL', 'Python', 'Django', 'Celery']",
#        "['Microsoft Excel', 'CRM', 'Hubspot']",
#        "['TypeScript', 'JavaScript', 'Figma', 'HTML', 'CSS', 'Vue', 'Tailwind', 'NodeJS', 'Angular2+', 'React']",
#        "['Microsoft Active Directory', 'Azure', 'Microsoft Office 365']",
#        "['Magento', 'Prestashop', 'BigCommerce', 'Salesforce']",
#        "['Java', 'Spring Boot', 'SQL', 'JavaScript', 'TypeScript', 'BigQuery', 'AWS']",
#        "['Hubspot', 'Python', 'SAP', 'Microsoft Power BI', 'Tableau']",
#        "['.NET', 'SQLServer', 'Git', 'Visual Studio', 'Angular2+', 'REST', 'SOAP']",
#        "['PHP', 'Symfony', 'AWS', 'React']", '[]',
#        "['BigCommerce', 'Prestashop', 'JavaScript', 'Vue', 'Angular2+', 'React', 'Figma', 'Tailwind']",
#        "['PHP', 'MySQL', 'Laravel', 'Symfony', 'Yii', 'React', 'Svelte']",
#        "['TypeScript', 'Nest', 'PostgreSQL', 'Docker', 'AWS']",
#        "['JavaScript', 'TypeScript', 'Vue', 'API', 'Github', 'Bootstrap', 'Nuxt.js', 'Leaflet', 'MapBox', 'ChartJS', 'Google Maps']",
#        "['AWS', 'Terraform', 'Kubernetes', 'Docker', 'Jenkins', 'Linux', 'MySQL', 'Databricks', 'GitLab']",
#        "['JavaScript', 'HTML', 'CSS', 'React', 'RxJS', 'Clojure', 'Rust']",
#        "['PHP', 'Symfony', 'REST', 'MySQL', 'Docker', 'Kubernetes', 'AWS']",
#        "['SQL', 'ETL', 'Selenium', 'Jmeter', 'Gatling', 'JavaScript', 'Python', 'AWS']",
#        "['Ruby on Rails', 'Vue', 'Python', 'MySQL', 'Nuxt.js']",
#        "['Python', 'SQL']",
#        "['React', 'JavaScript', 'TypeScript', 'Docker', 'AWS', 'Kubernetes', 'NextJS', 'NodeJS', 'Vue']",
#        "['ServiceNow']",
#        "['TypeScript', 'Vue', 'Github', 'AWS', 'Google Cloud']",
#        "['React', 'TypeScript']",
#        "['Azure', 'Microsoft Active Directory', 'Kafka', 'PowerShell', 'Java']",
#        "['Magento', 'Prestashop', 'Salesforce']",
#        "['Java', 'Spring Boot', 'AWS', 'Groovy', 'Kotlin', 'Quarkus', 'Jenkins']",
#        "['AWS', 'Python', 'Terraform']",
#        "['WordPress', 'Prestashop', 'WooCommerce', 'CSS', 'HTML', 'PHP']",
#        "['Python', 'Blender']",
#        "['.NET', 'C#', 'SQL', 'Azure', 'Swagger', 'Kubernetes', 'Terraform']",
#        "['Citrix', 'Windows', 'VMWare', 'PowerShell', 'Hyper-v', 'Xen', 'Google Cloud']",
#        "['Python', 'R', 'Docker', 'Kubernetes', 'SQL']",
#        "['Figma', 'Adobe Illustrator', 'Adobe Photoshop', 'HTML', 'CSS']",
#        "['Java', 'API', '.NET', 'Angular2+', 'DB2']",
#        "['GraphQL', 'React Native', 'Swift', 'Objective-C', 'Kotlin']",
#        "['Three.js', 'React', 'Python']",
#        "['Android', 'Java', 'SQL', 'MongoDB', 'Android Studio', 'C#', 'JavaScript']",
#        "['Python', 'Django', 'REST', 'NoSQL', 'PostgreSQL', 'Terraform', 'Google Cloud', 'Elasticsearch', 'Scrapy', 'React', 'TypeScript', 'Angular2+', 'Apache Beam']",
#        "['.NET', 'SQLServer', 'C#', '.Net Core', 'Azure', 'Docker', 'Kubernetes', 'Blazor', 'JavaScript', 'CSS', 'Vue']",
#        "['Linux', 'Nagios', 'Zabbix', 'Prometheus', 'Grafana', 'Kubernetes', 'Docker', 'Bash', 'DNS', 'HTTP4s', 'Ansible', 'Terraform', 'WordPress']",
#        "['Java', 'Spring', 'MySQL']",
#        "['Java', 'MySQL', 'MongoDB', 'Jenkins']",
#        "['Rust', 'WebSockets', 'MapBox', 'AWS']",
#        "['TypeScript', 'React', 'JavaScript', 'HTML', 'CSS']",
#        "['Kotlin', 'Docker', 'Kubernetes', 'AWS', 'NodeJS', 'Java', 'PHP', 'Symfony']",
#        "['.Net Core', '.NET', 'Angular2+', 'Razor']",
#        "['Python', 'SQL', 'TestingLibrary', 'JavaScript', 'HTML', 'CSS', 'Shiny', 'R', 'Git']",
#        "['Python', 'Blender', 'Git']",
#        "['Google Ads', 'Google Sheets', 'Pipedrive', 'CRM', 'Google Analytics', 'Notion', 'Trello', 'Monday']",
#        "['.NET', 'AWS', 'RabbitMQ', 'GraphQL', 'JavaScript', 'jQuery']",
#        "['Vue', 'TypeScript', 'HTML', 'CSS', 'Angular2+', 'React']",
#        "['Pytest', 'Python', 'C++', 'Jira', 'Xray']",
#        "['.Net Core', 'Entity', 'MySQL', 'Vue']",
#        "['Terraform', 'AWS', '.NET', 'Python']",
#        "['PHP', 'MySQL', 'CSS', 'HTML', 'Prestashop', 'JavaScript']",
#        "['JavaScript', 'TypeScript', 'React']",
#        "['React', 'GraphQL', 'React Native']",
#        "['PHP', 'API', 'Shopify', 'Laravel', 'Magento']",
#        "['Spring Boot', 'Java', 'SQL', 'CSS', 'JavaScript', 'HTML']",
#        "['Java', 'TypeScript', 'AWS', 'Kotlin', 'NodeJS', 'Kafka']",
#        "['JavaScript', 'Vue', 'Nest', 'NodeJS', 'TypeScript', 'PostgreSQL', 'MongoDB']",
#        "['TypeScript', 'React', 'Jest', 'React Native', 'Kotlin', 'Swift']",
#        "['PHP', 'Laravel', 'MySQL', 'NodeJS', 'Grafana', 'Go', 'Google Cloud', 'Redis', 'Docker']",
#        "['Python', 'SQL', 'Notion', 'DynamoDB', 'Java', 'React']",
#        "['Kubernetes', 'Docker', 'Ansible', 'KVM', 'MySQL', 'Solr']",
#        "['Java', 'Spring Boot', 'JUnit', 'MySQL', 'NoSQL', 'TypeScript', 'Angular2+']",
#        "['NodeJS', 'JavaScript', 'MongoDB', 'Docker', 'AWS Lambda', 'Kubernetes', 'Terraform']",
#        "['TypeScript', 'CSS', 'HTML', 'Angular2+', 'React', 'Kotlin']",
#        "['Java', 'Scala', 'Python', 'RabbitMQ', 'Kafka', 'MySQL', 'MongoDB']",
#        "['C#', '.NET', '.Net Core', 'SQL', 'Vue', 'Azure']",
#        "['Docker', 'Linux', 'Ansible', 'PostgreSQL', 'RabbitMQ', 'Azure', 'Redis', 'Windows']",
#        "['AWS', 'Azure', 'Terraform', 'Docker', 'Kubernetes', 'Python', 'TypeScript', 'Java']",
#        "['JavaScript', 'React', 'Ethereum', 'Web3']",
#        "['Angular2+', 'HTML', 'CSS', 'JavaScript', 'Java', 'Spring Boot']",
#        "['.NET', '.Net Core', 'SQLServer', 'Azure', 'AWS', 'Angular2+']",
#        "['Kotlin', 'Python', 'Java', 'React', 'Google Cloud', 'NodeJS']",
#        "['Laravel', 'MySQL', 'API', 'PHPunit', 'Vue']",
#        "['Python', 'Django', 'SQL', 'REST', 'Docker', 'JavaScript', 'Linux', 'AWS']",
#        "['Atlassian', 'Jira', 'Python', 'Jenkins']",
#        "['Vue', 'Vuex', 'TypeScript', 'Nuxt.js', 'CSS']",
#        "['NextJS', 'React', 'AngularJS', 'Vue']",
#        "['TypeScript', 'JavaScript', 'Angular2+', 'HTML']",
#        "['Fastapi', 'TensorFlow', 'Kubernetes', 'Pytest']",
#        "['Jira', 'SQL', 'Amplitude']", "['C++', 'C#']",
#        "['AWS', 'Terraform', 'Docker', 'Kubernetes', 'Helm', 'Prometheus', 'Grafana']",
#        "['Java', 'Spring Boot', 'REST', 'Go', 'NodeJS', 'Kubernetes']",
#        "['NodeJS', 'TypeScript', 'PostgreSQL', 'MongoDB', 'React']",
#        "['HTML', 'CSS', 'Angular2+', 'React', 'Vue', 'PHP']",
#        "['Java', 'Spring Boot', 'JavaScript', 'PostgreSQL', 'AWS', 'React']",
#        "['Java', 'Spring', 'junit4', 'Github', 'Docker', 'Ansible', 'Kubernetes']",
#        "['Linux', 'MySQL', 'AWS', 'Google Cloud', 'PostgreSQL', 'Elasticsearch', 'Cassandra']",
#        "['Python', 'Django', 'Git', 'PostgreSQL', 'AWS', 'Celery']",
#        "['Swift', 'SwiftUI']",
#        "['PHP', 'Symfony', 'MySQL', 'Git', 'API', 'REST', 'Kafka', 'RabbitMQ']",
#        "['JavaScript', 'Vue', 'TypeScript', 'NodeJS']",
#        "['NodeJS', 'MongoDB', 'Git', 'MySQL', 'Docker', 'AWS', 'Kubernetes']",
#        "['Python', 'SQL', 'MongoDB', 'Fastapi', 'PyTorch', 'TensorFlow']",
#        "['Java', 'AWS', 'Spring', 'Hibernate', 'NodeJS', 'Kafka', 'SQL', 'Kotlin']",
#        "['Linux', 'SQL', 'Bash', 'Python', 'Docker', 'AWS', 'New Relic']",
#        "['Python', 'Pandas', 'Numpy', 'Docker', 'AWS', 'RabbitMQ']",
#        "['SQL', 'REST', 'Java', 'Go', 'Python', 'SOAP']",
#        "['PHP', 'Docker', 'API', 'Git', 'Magento']",
#        "['SQLServer', 'PowerShell', 'IIS', 'Docker', 'Kubernetes', 'Azure']",
#        "['Angular2+', 'TypeScript', 'NgRx', 'nestJS']",
#        "['Java', 'Maven', 'JUnit', 'GitLab', 'AWS']",
#        "['Angular2+', 'NgRx', 'TypeScript', 'nestJS']",
#        "['Java', 'Spring Boot', 'REST', 'PostgreSQL', 'Kubernetes', 'Docker', 'ActiveMQ', 'SOAP', 'Angular2+']",
#        "['PHP', 'Symfony', 'MySQL', 'Git', 'NodeJS', 'Kubernetes', 'AWS']",
#        "['Vue', 'Vuex', 'Nuxt.js', 'TypeScript', 'CSS']",
#        "['Java', 'Python', 'PostgreSQL', 'SQL', 'Kafka', 'AWS']",
#        "['PHP', 'Git', 'Docker', 'API', 'Magento']",
#        "['Microsoft', 'AWS', 'Azure']",
#        "['TypeScript', 'CSS', 'Angular2+', 'Azure', 'Docker']",
#        "['.NET', 'C#', 'MySQL', 'javacript', 'MongoDB', 'Kotlin']",
#        "['HTML', 'CSS', 'JavaScript', 'TypeScript', 'Sass', 'React', 'Docker', 'AWS']",
#        "['Figma', 'Sketch', 'Adobe Xd', 'Axure', 'CSS']",
#        "['JavaScript', 'TypeScript', 'Svelte', 'Go', 'Ruby on Rails']",
#        "['Trello', 'Postman', 'Cypress', 'Selenium', 'Notion']",
#        "['Git', 'Flutter', 'React']", "['Java', 'Spring Boot', 'AWS']",
#        "['Jenkins', 'Elasticsearch', 'Kibana']",
#        "['Linux', 'Kubernetes', 'Google Cloud', 'Helm', 'GitLab']",
#        "['PHP']", "['NodeJS', 'SQL', 'Express', 'Nest', 'Docker', 'AWS']",
#        "['React', 'TypeScript', 'NextJS', 'Git', 'Jest', 'Cypress', 'React Native']",
#        "['PHP', 'MySQL', 'Google Analytics', 'Cordova', 'Figma']",
#        "['Python', 'MongoDB', 'Docker', 'screen-scraping', 'Jenkins']",
#        "['JavaScript', 'TypeScript', 'React', 'Jest', 'Cypress', 'NextJS']",
#        "['Apple iOS', 'SwiftUI']",
#        "['Swift', 'Git', 'Github', 'SwiftUI', 'BlueTooth']",
#        "['TypeScript', '.NET', 'AWS', 'Swagger', 'Angular2+', 'GraphQL', 'Java', 'Apache']",
#        "['Python', 'Django', 'REST', 'AWS', 'Docker']",
#        "['C#', 'Angular2+']",
#        "['.NET', '.Net Core', 'Azure', 'Angular2+', 'SQLServer']",
#        "['React', 'JavaScript', 'CSS', 'Redux', 'TypeScript']",
#        "['Jira']",
#        "['React Native', 'TypeScript', 'TestFlight', 'Figma']",
#        "['Vue', 'JavaScript', 'TypeScript', 'VanillaJS', 'Cypress', 'CSS', 'Laravel', 'Figma', 'Tailwind']",
#        "['JavaScript', 'NodeJS', 'nestJS']",
#        "['NodeJS', 'Docker', 'TypeScript', 'RabbitMQ', 'Kubernetes', 'MongoDB', 'PostgreSQL', 'Elasticsearch']",
#        "['Google Cloud', 'Kubernetes', 'Jenkins', 'Terraform', 'PHP', 'AWS']",
#        "['JavaScript', 'TypeScript', 'React', 'Blazor', 'Azure', 'C#']",
#        "['React', 'CSS', 'TypeScript', 'NextJS', 'Tailwind']",
#        "['C#', '.NET', '.Net Core', 'SQL', 'Vue']",
#        "['Vue', 'TypeScript', 'Jest', 'TestingLibrary', 'Tailwind']",
#        "['Magento', 'Docker', 'Git', 'API']",
#        "['Ruby on Rails', 'API', 'SQL', 'AWS']",
#        "['Java', 'AWS', 'Docker', 'Spring', 'Terraform', 'Go', 'Python']",
#        "['Odoo', 'SQL', 'SQLServer', 'Python']",
#        "['AWS', 'Docker', 'Terraform', 'Linux', 'Kubernetes', 'Ansible']",
#        "['Swift', 'Apple iOS', 'Figma']", "['Productboard']",
#        "['Java', 'Spring', 'Kafka', 'Docker', 'Terraform', 'Kubernetes', 'AWS']",
#        "['Angular2+', 'Ionic', 'Git', 'C', 'Java', 'C#', 'Cordova']",
#        "['Linux', 'Docker', 'Apache', 'MySQL', 'Kubernetes', 'Nagios', 'Prometheus']",
#        "['Swift', 'Objective-C']",
#        "['JavaScript', 'TypeScript', 'WebApi', 'RollupJS']",
#        "['Java', 'Kotlin', 'AWS', 'Spring', 'Hibernate', 'NodeJS', 'Kafka', 'SQL']",
#        "['AWS', 'Python', 'Go']",
#        "['NodeJS', 'TypeScript', 'MongoDB', 'AWS']",
#        "['Google Ads', 'Google AdManager', 'WordPress', 'Google Data Studio', 'Google Analytics', 'Google Tag Manager', 'Google Optimize']",
#        "['Swift', 'Apple iOS', 'Google Analytics', 'Google Firebase', 'Redux']",
#        "['C#', '.Net Core', 'Angular2+', 'SQL', 'Azure']",
#        "['Java', 'React', 'Kotlin', 'AWS', 'Spring', 'NodeJS', 'Kafka', 'Elasticsearch']",
#        "['Java', 'Spring', 'Angular2+', 'Ionic', 'TypeScript', 'Google Cloud']",
#        "['Java', 'JUnit', 'Maven', 'GitLab', 'Couchbase', 'AWS']",
#        "['JavaScript', 'Cypress', 'Postman', 'Appium']",
#        "['Python', 'SQL', 'Docker', 'Kubernetes', 'Google Cloud']",
#        "['Vue', 'Adobe Photoshop']",
#        "['Cypress', 'Selenium', 'Cucumber', 'Ruby on Rails', 'NodeJS']",
#        "['Figma', 'Adobe Illustrator', 'Adobe Photoshop', 'Notion', 'HTML', 'CSS']",
#        "['JavaScript', 'React', 'Redux', 'Sagas', 'WordPress', 'Apollo', 'GraphQL', 'Jest', 'Mocha']",
#        "['.Net Core', 'Entity', 'Vue', 'Angular2+', 'React', 'Elasticsearch']",
#        "['Java', 'Spring Boot', 'Kubernetes', 'NodeJS', 'JavaScript']",
#        "['Ruby', 'MongoDB', 'Redis', 'Docker', 'Terraform', 'AWS']",
#        "['PHP', 'Symfony']",
#        "['JavaScript', 'Svelte', 'TypeScript', 'Go']",
#        "['.Net Core', 'Angular2+', 'Razor']",
#        "['CSS', 'React', 'HTML', 'Vue']",
#        "['Java', 'Groovy', 'Terraform', 'Micronaut Framework']",
#        "['Java', 'Spring', 'Angular2+', 'KendoUI', 'AWS']",
#        "['NodeJS', 'RabbitMQ', 'Docker', 'Kubernetes', 'TypeScript', 'MongoDB', 'PostgreSQL', 'Elasticsearch', 'Kafka']",
#        "['PHP', 'Vue', 'Yii', 'SQL', 'AWS', 'Android']",
#        "['JavaScript', 'Ember', 'React', 'Angular2+']",
#        "['Angular2+', 'JavaScript', 'TypeScript', 'AngularJS', 'MySQL', 'Java']",
#        "['JavaScript', 'AWS', 'MongoDB', 'Linux', 'NodeJS', 'TypeScript', 'Vue', 'Elasticsearch']",
#        "['Terraform', 'Docker', 'MySQL', 'PHP']",
#        "['PHP', 'MySQL', 'C++', 'Docker']",
#        "['JavaScript', 'AngularJS', 'Angular2+', 'C#']",
#        "['Github', 'Jest', 'Puppeteer', 'JavaScript', 'Kubernetes', 'Selenium']",
#        "['Google Analytics', 'Google Firebase', 'Jira', 'Trello', 'Figma', 'Miro']",
#        "['HTML', 'CSS', 'JavaScript', 'NextJS', 'Vue', 'React', 'Angular2+', 'NodeJS', 'TypeScript', 'Backbone']",
#        "['Angular2+', 'GraphQL', 'Redux']",
#        "['AWS', 'Github', 'Docker', 'Kubernetes', 'JavaScript', 'Helm', 'CMS']",
#        "['Kotlin', 'Android', 'MVC']",
#        "['WordPress', 'HTML', 'Hubspot', 'Trello', 'Google Cloud']",
#        "['Apple iOS', 'Swift', 'MVVM']",
#        "['Vue', 'Jira', 'Express', 'Google Firebase', 'NoSQL', 'NodeJS']",
#        "['Ruby on Rails']", "['React', 'Redux', 'Jest']",
#        "['React', 'Java', 'SQL', 'AWS', 'Kafka', 'ClickHouse']",
#        "['Linux', 'Kubernetes', 'Docker', 'Apache', 'MySQL', 'Nagios', 'Prometheus']",
#        "['Python', 'PostgreSQL', 'SQL', 'Kafka', 'AWS']",
#        "['JavaScript', 'React']",
#        "['NodeJS', 'REST', 'MongoDB', 'TypeScript', 'Docker', 'Python', 'Ansible', 'Kubernetes']",
#        "['Linux', 'Python', 'Terraform', 'AWS-User', 'Jenkins', 'Github']",
#        "['Java', 'Spring', 'SQL', 'JavaScript', 'AWS', 'Kubernetes', 'Docker']",
#        "['PHP', 'Symfony', 'MySQL', 'HTML', 'CSS']", "['Linux', 'AWS']",
#        "['Java', 'MySQL', 'JavaScript', 'Scala', 'Docker', 'Jenkins', 'Ansible']",
#        "['Docker', 'Azure', 'AWS']",
#        "['PHP', 'Git', 'JavaScript', 'HTML', 'CSS', 'Laravel', 'Symfony', 'MySQL']",
#        "['NodeJS', 'MongoDB', 'AngularJS']",
#        "['Python', 'Linux', 'Docker']",
#        "['SQL', 'Python', 'AWS', 'Java']",
#        "['C#', 'SQL', 'AngularJS', 'ASP.net']",
#        "['TestNg', 'MySQL', 'MariaDB', 'PHP', 'Java', 'Python', 'Keycloak', 'Jenkins']",
#        "['Jenkins', 'Azure', 'Git', 'SonarQube', 'Groovy', 'Nexus', 'Java']",
#        "['Ruby']", "['React', 'TypeScript', 'Vue', 'AWS', 'NodeJS']",
#        "['Java', 'PostgreSQL', 'Elasticsearch', 'slq-server']",
#        "['JavaScript', 'HTML', 'CSS', 'React', 'GraphQL', 'NodeJS', 'React Native']",
#        "['Java', 'MongoDB', 'Elasticsearch', 'AWS', 'NodeJS', 'Kafka']",
#        "['Python', 'Snowflake', 'Airflow', 'Redshift', 'AWS', 'Scala']",
#        "['Terraform', 'AWS', 'Prometheus', 'Grafana', 'Elasticsearch', 'PostgreSQL', 'Jenkins', 'Python', 'Golang', 'Java', 'GraalVM']",
#        "['API', 'Python', 'Go', 'Kong', 'Lua', 'Kubernetes']",
#        "['PHP', 'Laravel', 'AWS', 'Angular2+']",
#        "['Jenkins', 'GitLab', 'CircleCI', 'AWS', 'Java']",
#        "['Ruby', 'JavaScript', 'AWS', 'MySQL', 'Elasticsearch', 'Vue']",
#        "['JavaScript', 'NodeJS', 'SQL', 'Jest', 'TypeScript', 'Docker', 'Kubernetes']",
#        "['Java', 'Spring Boot', 'Flutter', 'AWS']",
#        "['Symfony', 'MySQL', 'Git', 'MongoDB', 'Elasticsearch', 'Webpack']",
#        "['NodeJS', 'TypeScript', 'JavaScript']",
#        "['PHP', 'Laravel', 'Symfony', 'Git', 'JavaScript', 'Angular2+', 'React', 'Vue', 'Docker']",
#        "['PHP', 'AWS', 'Flutter']",
#        "['Angular2+', 'JavaScript', 'HTML', 'CSS', 'RxJS', 'FlexBox', 'Jest', 'Docker', 'PHP', 'Symfony']",
#        "['SQL', 'HTML', 'CSS', 'JavaScript', 'Ruby on Rails', 'AWS', 'Ruby']",
#        "['Unix', 'AWS', 'Docker', 'Terraform', 'Jenkins']",
#        "['Java', 'Spark', 'AWS', 'Python', 'Scala']",
#        "['AWS', 'Docker', 'Python', 'Ansible', 'PostgreSQL', 'Azure']",
#        "['JavaScript', 'SQL', 'HTML', 'CSS', 'Ruby', 'Ruby on Rails', 'AWS']",
#        "['Java', 'Spring Boot', 'Docker', 'AWS']",
#        "['React', 'JavaScript', 'HTML', 'CSS', 'Redux', 'NextJS']",
#        "['Linux', 'Ansible', 'Terraform', 'Kubernetes', 'AWS', 'Elasticsearch', 'PostgreSQL']",
#        "['AWS', 'Docker', 'SQL', 'Symfony', 'Elasticsearch', 'Jenkins', 'NodeJS']",
#        "['Python', 'SQL', 'Pandas', 'AWS', 'MongoDB']",
#        "['Spark', 'SQL', 'Python']",
#        "['JavaScript', 'HTML', 'CSS', 'React', 'NodeJS']",
#        "['.NET', 'Pulumi', 'Azure', 'Kafka', 'NodeJS']",
#        "['PHP', 'JavaScript', 'Linux', 'NodeJS', 'Laravel']",
#        "['Kotlin', 'Ruby on Rails', 'Spring Boot', 'Docker', 'AWS']",
#        "['NodeJS', 'Vue', 'MongoDB', 'AWS']",
#        "['Python', 'MongoDB', 'Docker', 'screen-scraping', 'Google Cloud', 'Django']",
#        "['Java', 'Spring', 'NodeJS', 'MySQL', 'AWS']",
#        "['Objective-C', 'Java', 'Swift', 'Kotlin']",
#        "['NodeJS', 'MongoDB', 'MySQL', 'AWS', 'Jenkins', 'GraphQL']",
#        "['Ruby on Rails', 'Java', 'PHP', 'javacript', 'Python']",
#        "['Android', 'Kotlin', 'AWS', 'Python']",
#        "['Java', 'MySQL', 'Spring', 'React', 'NodeJS']",
#        "['CSS', 'HTML', 'Figma', 'JavaScript', 'Angular2+']",
#        "['Java', 'Spring', 'JavaScript', 'AWS']",
#        "['PHP', 'MySQL', 'JavaScript', 'HTML']",
#        "['Kotlin', 'Android', 'Google Analytics', 'Google Firebase', 'Redux']",
#        "['Ruby on Rails', 'NodeJS', 'Python']",
#        "['JavaScript', 'React', 'HTML', 'CSS', 'Ruby on Rails']",
#        "['PHP', 'Laravel', 'Symfony', 'Elasticsearch', 'AWS', 'PostgreSQL']",
#        "['JavaScript', 'HTML', 'CSS', 'React']",
#        "['PHP', 'Symfony', 'MySQL', 'Jenkins', 'JavaScript', 'AWS', 'Elasticsearch']",
#        "['AWS', 'Linux', 'Azure', 'Jenkins', 'Terraform', 'Ansible']",
#        "['Figma', 'HTML', 'CSS', 'JavaScript']",
#        "['JavaScript', 'NodeJS', 'MongoDB', 'MySQL', 'React']",
#        "['AWS', 'Python', 'Go', 'Linux']", "['Android', 'Kotlin']",
#        "['NodeJS', 'TypeScript', 'PostgreSQL']",
#        "['AWS', 'Terraform', 'Ansible', 'Kubernetes', 'Docker']",
#        "['NodeJS', 'JavaScript', 'Express', 'MongoDB', 'AWS']",
#        "['Python', 'AWS', 'Ruby']",
#        "['Azure', 'Linux', 'Jenkins', 'Terraform', 'Ansible']",
#        "['Java', 'AWS']", "['SAP', 'Salesforce']",
#        "['Figma', 'CSS', 'HTML', 'Angular2+']",
#        "['HTML', 'CSS', 'JavaScript', 'React', 'NextJS']",
#        "['.NET', 'C#', 'PostgreSQL', 'RabbitMQ', 'Java']",
#        "['Java', 'Docker', 'Kotlin', 'Spring', 'AWS', 'Jenkins', 'Kubernetes']",
#        "['PHP', 'Laravel', 'Angular2+', 'Vue', 'React']",
#        "['Python', 'Pandas', 'Docker', 'Spark']",
#        "['Terraform', 'Linux', 'Kubernetes', 'Docker', 'Google Cloud']",
#        "['NodeJS', 'JavaScript', 'Angular2+', 'React', 'TypeScript']",
#        "['AngularJS', 'HTML', 'CSS', 'Nginx', 'NodeJS']",
#        "['Android', 'Java', 'Kotlin', 'React Native', 'Cordova']",
#        "['NodeJS', 'MongoDB', 'AWS', 'Vue']",
#        "['Go', 'C++', 'AWS', 'MongoDB', 'Vue']",
#        "['SQL', 'Python', 'AWS', 'Kafka']",
#        "['PHP', 'NodeJS', 'React', 'Vue', 'Go', 'Python']",
#        "['Microsoft WPF', '.NET', 'C#', 'C++', 'Angular2+']",
#        "['PHP', 'MySQL', 'Laravel', 'Symfony', 'AWS']",
#        "['Java', 'React']",
#        "['TypeScript', 'JavaScript', 'NodeJS', 'MongoDB', 'PostgreSQL', 'React', 'AWS']",
#        "['AWS', 'Terraform', 'Docker', 'Kubernetes', 'Jenkins', 'Python']",
#        "['JavaScript', 'Apple iOS', 'Android', 'TypeScript', 'React Native', 'Google Cloud']",
#        "['PHP', 'JavaScript', 'HTML', 'Linux', 'React', 'Angular2+', 'Vue', 'Ansible']",
#        "['JavaScript', 'Google Analytics', 'Google Firebase', 'Google Tag Manager', 'Adobe Launch', 'Adobe Target', 'Angular2+', 'HTML', 'BigQuery', 'Apple iOS']",
#        "['PHP', 'Symfony', 'MySQL', 'CSS', 'HTML', 'Bootstrap', 'Vue', 'React']",
#        "['.NET', 'C#', 'C++', 'Angular2+']",
#        "['MySQL', 'PHP', 'HTML', 'Laravel', 'CSS', 'JavaScript', 'PostgreSQL', 'React', 'Vue']",
#        "['Symfony', 'PHP', 'Python', 'Go', 'React']",
#        "['CSS', 'HTML', 'JavaScript', 'Vue', 'React', 'Angular2+', 'Invision', 'Salesforce', 'Webpack', 'Sketch']",
#        "['Linux', 'Azure', 'Jenkins', 'Terraform', 'Ansible']",
#        "['NodeJS', 'nestJS', 'TypeScript', 'MongoDB', 'API', 'Python', 'Docker', 'GitHub Actions', 'Google Cloud', 'Kafka', 'GraphQL', 'gRPC']",
#        "['JavaScript', 'HTML', 'CSS', 'NodeJS', 'Vue', 'MongoDB', 'AWS']",
#        "['MongoDB', 'JavaScript', 'TypeScript', 'NodeJS', 'Jest', 'DialogFlow', 'WebSockets']",
#        "['Terraform', 'AWS', 'AWS ECS', 'PostgreSQL', 'Python', 'Jenkins']",
#        "['Apple iOS', 'Swift', 'Core Data', 'Combine', 'Figma']",
#        "['Vue', 'CSS', 'HTML', 'PHP', 'Figma']",
#        "['PHP', 'SQL', 'Git', 'Laravel', 'Shopify', 'NodeJS', 'RabbitMQ']",
#        "['Ruby on Rails', 'GraphQL', 'PostgreSQL', 'Docker']",
#        "['NodeJS', 'TypeScript', 'MongoDB', 'Linux', 'Kubernetes', 'AWS', 'GitLab', 'Argo CD']",
#        "['Python', 'C++', 'Cinema 4D']",
#        "['AWS', 'Python', 'PostgreSQL', 'MySQL', 'NodeJS', 'JavaScript']",
#        "['Kubernetes', 'Terraform', 'AWS', 'Java', 'Golang', 'Python', 'Argo CD', 'Prometheus']",
#        "['C#', '.NET', 'SQL', 'JSON', 'Angular2+']",
#        "['Webflow', 'Figma', 'Sketch', 'Adobe Xd', 'HTML', 'CSS', 'Google Analytics']",
#        "['z/OS', 'DB2', 'PowerShell', 'Bash']",
#        "['JavaScript', 'NextJS', 'Express', 'Koa', 'MySQL', 'NodeJS', 'Google Cloud']",
#        "['TypeScript', 'React', 'NextJS', 'CSS', 'Tailwind']",
#        "['Python', 'Django', 'SQL', 'AWS', 'Docker', 'Celery', 'PostgreSQL', 'Fastapi']",
#        "['PHP', 'Symfony', 'Vue', 'JavaScript', 'MySQL', 'NodeJS', 'Python', 'AWS']",
#        "['AWS', 'Docker', 'Terraform', 'GitLab']",
#        "['Java', 'Spring', 'Hibernate', 'Github', 'API', 'WebSockets', 'AWS', 'PostgreSQL', 'MySQL', 'HTML', 'CSS', 'Svelte']",
#        "['C++', 'CMake', 'Git', 'Qt']", "['Linux', 'Ansible']",
#        "['Java', 'Alfresco', 'Docker', 'PostgreSQL']",
#        "['AWS', 'SQLServer', 'S3', 'Redshift', 'PostgreSQL', 'Snowflake']",
#        "['JavaScript', 'NodeJS', 'React', 'TypeScript', 'AWS', 'SQL', 'Git', 'Python', 'Auth0', 'Tableau', 'ETL']",
#        "['Apple iOS', 'Android', 'Java', 'Kotlin']", "['Hubspot']",
#        "['.NET', 'C#', 'SQL', 'Angular2+', 'React', 'Vue', 'TypeScript', 'Azure', 'Azure DevOps']",
#        "['Cypress', 'Selenium', 'JavaScript', 'Appium']",
#        "['GitLab', 'Selenium', 'Appium', 'Cypress']",
#        "['BigQuery', 'Google Firebase', 'Android', 'Apple iOS']",
#        "['Python', 'SQL', 'AWS', 'Spark', 'Tableau', 'dbt']",
#        "['Swift', 'Apple iOS', 'SwiftUI', 'XCTest', 'UIKit']",
#        "['Python', 'SQL', 'Django', 'Flask', 'Fastapi']",
#        "['Atlassian', 'Terraform', 'Ansible', 'Azure', 'Jenkins', 'Kubernetes', 'Groovy', 'Python', 'Angular2+', 'Bash']",
#        "['Kubernetes', 'Terraform', 'AWS', 'Prometheus', 'Python', 'Go']",
#        "['C#', 'SQL', '.Net Core', 'Azure', 'Swagger', 'Kubernetes', 'Terraform']",
#        "['MySQL', 'PostgreSQL', 'PHP', 'Vue', 'React']",
#        "['.Net Core', 'SQL', '.NET', 'Vue', 'Azure']",
#        "['SQL', 'dbt', 'Python', 'Metabase', 'BigQuery']",
#        "['UML', 'Java', 'Flutter', 'Dart', 'C++', 'C', 'Kotlin']",
#        "['Python', 'C#', 'Azure', 'Elasticsearch']",
#        "['Python', 'REST', 'Django', 'JavaScript', 'React']",
#        "['SQL', 'PowerShell', 'Genesys', 'Python', 'DialogFlow', 'SIP']",
#        "['TypeScript', 'React', 'NextJS', 'Docker', 'AWS']",
#        "['Java', 'Spring Boot', 'SQL', 'Salesforce', 'GitLab']",
#        "['Azure', 'Kubernetes', 'Docker', 'Terraform', 'Python', 'API', 'REST', 'Spark', 'Hadoop', 'React', 'Angular2+']",
#        "['C#', '.Net Core', '.NET', 'SQLServer', 'Kubernetes', 'Azure']",
#        "['SQL', 'Java']", "['Jira', 'Trello']",
#        "['Jira', 'PHP', 'React', 'AWS', 'React Native']",
#        "['Python', 'Django', 'PostgreSQL', 'Docker']",
#        "['Java', 'Spring Boot', 'Kafka', 'Azure', 'AWS', 'Docker', 'TypeScript', 'Vue']",
#        "['Java', 'Spring', 'Kafka', 'Jenkins', 'Docker', 'Vue']",
#        "['NodeJS', 'MongoDB', 'Jest', 'TypeScript', 'JavaScript', 'WebSockets', 'DialogFlow']",
#        "['.NET', 'Terraform', 'AWS']",
#        "['Python', 'SQL', 'API', 'Git', 'BigQuery']",
#        "['JavaScript', 'NodeJS', 'MongoDB', 'PostgreSQL', 'TypeScript', 'AWS']",
#        "['React', 'CSS', 'HTML', 'JavaScript', 'Sass', 'Ember', 'Tailwind', 'NextJS', 'Python', 'Ruby on Rails']",
#        "['Jira', 'Xray', 'AWS Cloudwatch', 'Grafana']",
#        "['Docker', 'Kubernetes', 'Terraform', 'Google Cloud', 'Go']",
#        "['.NET', 'Angular2+', 'C#', 'SQL', 'Azure']",
#        "['.Net Core', '.NET', 'MySQL']",
#        "['.Net Core', '.NET', 'Vue', 'Angular2+', 'React']",
#        "['MongoDB', 'Git', 'VanillaJS', 'React', 'PHP', 'AWS', 'WordPress']",
#        "['Drupal', 'REST', 'JavaScript', 'HTML', 'CSS', 'Laravel', 'Magento']",
#        "['Java', 'Spring', 'SQL', 'MongoDB', 'AWS']",
#        "['PHP', 'Symfony', 'MySQL', 'Git', 'TypeScript', 'NodeJS', 'Kubernetes', 'AWS']",
#        "['Dart', 'Flutter', 'Git']",
#        "['Azure', 'AWS', 'Google Cloud', 'Github Actions', 'JavaScript', 'OpenApi', 'Go', 'Rust', 'Python', 'MongoDB', 'Redis', 'Web3', 'Ethereum']",
#        "['Jira', 'Notion', 'Slack']", "['SQL', 'PL/SQL', 'Oracle']",
#        "['SQL', 'Airflow', 'Tableau', 'GitLab', 'Amplitude', 'Mixpanel']",
#        "['JavaScript', 'Vue', 'TypeScript', 'Figma', 'Jest', 'React']",
#        "['Python', 'Django', 'Linux', 'Git', 'Celery', 'PostgreSQL', 'MongoDB', 'Redis', 'Angular2+', 'JavaScript']",
#        "['AWS', 'Docker', 'Linux', 'Ansible', 'Python', 'Prometheus', 'Grafana', 'Github Actions', 'Terraform']",
#        "['Python', 'Flask', 'PostgreSQL', 'MongoDB', 'Sklearn']",
#        "['Google Cloud', 'Kubernetes', 'Docker', 'Linux', 'Terraform', 'Go', 'KVM', 'Github Actions']",
#        "['SQL', 'Python', 'Java', 'BigQuery', 'Google Looker Studio', 'dbt']",
#        "['PHP', 'Laravel', 'PostgreSQL', 'MySQL', 'JavaScript', 'HTML', 'CSS', 'Vue', 'Python']",
#        "['C#', '.NET', 'WPF', 'FlaUI', 'Angular2+', 'Gherkin', 'Specflow', 'Playwright']",
#        "['NodeJS', 'Express', 'Python', 'Gitflow', 'AWS', 'React']",
#        "['Jenkins', 'Git', 'SonarQube', 'Groovy', 'Nexus', 'Azure', 'Java']",
#        "['Docker', 'Kubernetes', 'AWS', 'PostgreSQL', 'Python', 'Terraform']",
#        "['Python', 'PyTorch', 'Kubernetes', 'Pytest']",
#        "['Azure', 'SQL', 'PHP', '.NET', 'Windows', 'Linux', 'Fortinet', 'Cisco']",
#        "['Flutter', 'Kotlin', 'Google Firebase', 'Riverpod', 'Google Cloud', 'gRPC', 'Protobuf']",
#        "['Vue', 'TypeScript', 'Figma', 'React', 'REST', 'NodeJS']",
#        "['Spring', 'Java', 'Elasticsearch', 'AWS']",
#        "['Java', 'Spark', 'AWS', 'SQL', 'Terraform', 'Docker', 'Scala', 'Kafka']",
#        "['Python', 'SQL', 'Google Cloud', 'dbt']",
#        "['JavaScript', 'Vue', 'Jest', 'Vitest', 'Tailwind', 'Webpack', 'Vite']",
#        "['F5', 'Apache', 'Aruba', 'Cisco', 'Infoblox', 'Palo Alto', 'Zscaler', 'MobileIron', 'PRTG', 'VMware NSX']",
#        "['Python', 'Fastapi', 'Kubernetes', 'Pytest']",
#        "['AWS', 'Docker', 'Python', 'Ansible', 'PostgreSQL', 'Azure', 'Google Cloud', 'Terraform']",
#        "['Android', 'Java', 'Kotlin', 'SQL', 'Vue']",
#        "['Java', 'Spring', 'MongoDB', 'AWS', 'Google Cloud', 'JavaScript', 'Python']",
#        "['Java', 'Spring Boot', 'REST', 'PostgreSQL', 'Go', 'Docker', 'ActiveMQ', 'SOAP', 'Angular2+']",
#        "['Python', 'Django', 'PostgreSQL', 'Docker', 'Fastapi', 'Kubernetes', 'MongoDB']",
#        "['React', 'JavaScript', 'NodeJS', 'GraphQL', 'AngularJS', 'Vue']",
#        "['JavaScript', 'NodeJS', 'Express', 'MongoDB', 'TypeScript']",
#        "['Microsoft Sharepoint', 'C#', 'React', 'Azure', 'Microsoft Dynamics 365']",
#        "['Angular2+', 'TypeScript', 'CSS', 'RxJS', 'NodeJS', 'NgRx', 'Bootstrap', 'Webpack']",
#        "['Swift', 'Apple iOS', 'Core Data', 'Figma']",
#        "['Python', 'AWS', 'Git', 'DynamoDB', 'MongoDB', 'Github Actions']",
#        "['PHP', 'Laravel', 'API', 'MySQL', 'Google Cloud', 'Redis']",
#        "['AngularJS', 'HTML', 'CSS', 'Ionic', 'Nginx', 'NodeJS']",
#        "['Python', 'MongoDB', 'Fastapi', 'PyTorch', 'Docker', 'TensorFlow', 'AWS SageMaker']",
#        "['Android', 'Apple iOS']",
#        "['PHP', 'Git', 'MySQL', 'RabbitMQ', 'Symfony']",
#        "['Java', 'Spring Boot', 'Git', 'PostgreSQL', 'MongoDB', 'Docker', 'AWS', 'RabbitMQ']",
#        "['MongoDB', 'SQLServer', 'Oracle', 'SQL']",
#        "['PHP', 'WordPress', 'HTML', 'CSS', 'JavaScript']",
#        "['Microsoft Power BI', 'SQL', 'Google Tag Manager', 'Google Analytics', 'Python', 'API']",
#        "['Linux', 'AWS', 'Plesk']", "['Go', 'React']",
#        "['Python', 'SQL', 'SCADA']",
#        "['JavaScript', 'React', 'AWS', 'CSS', 'HTML', 'Python']",
#        "['Cypress', 'Jenkins', 'XCTest', 'Postman', 'Jmeter', 'SonarQube']",
#        "['Python', 'JavaScript', 'TypeScript', 'PostgreSQL', 'HTML', 'CSS', 'Docker', 'MongoDB', '.NET', 'C#', 'Blazor', 'MVC']",
#        "['SQL', 'AWS', 'Python']",
#        "['Java', 'Spring Boot', 'Spring', 'Docker', 'Kubernetes', 'Ansible']",
#        "['React', 'TypeScript', 'JavaScript', 'React Native', 'Figma', 'CSS', 'HTML']",
#        "['PHP', 'Docker', 'JavaScript', 'NodeJS', 'AWS', 'Symfony']",
#        "['PHP', 'Laravel', 'MySQL', 'Python', 'Docker', 'React']",
#        "['Java', 'Spring', 'AWS', 'MongoDB', 'MySQL']",
#        "['JBoss', 'Linux', 'Windows', 'VMWare', 'Microsoft', 'Ansible', 'Docker']",
#        "['SQL', 'Microstrategy', 'BI', 'Tableau', 'Adobe Analytics', 'Google Analytics', 'Adobe Campaign', 'Salesforce', 'Selligent', 'Python']",
#        "['SQL', 'Adobe Campaign', 'Tableau', 'BI', 'Microstrategy', 'Google Analytics', 'Adobe Analytics']",
#        "['.NET', 'Java', 'Transact-SQL (T-SQL)', 'PL/SQL']", "['Azure']",
#        "['NodeJS', 'MongoDB', 'AngularJS', 'AWS']",
#        "['JavaScript', 'NodeJS', 'TypeScript', 'PostgreSQL', 'MongoDB']",
#        "['Vue', 'TypeScript', 'Jest']",
#        "['Angular2+', 'JavaScript', 'TypeScript', 'HTML', 'CSS', 'Jest', 'Jasmine', 'Docker', 'Webpack']",
#        "['MongoDB', 'Oracle', 'SQLServer', 'SQL']",
#        "['JavaScript', 'Vue', 'TypeScript', 'Nuxt.js', 'Webpack', 'Babel', 'AWS', 'Google Cloud', 'Azure']",
#        "['TypeScript', 'NodeJS', 'PHP', 'Laravel', 'nestJS', 'Java', 'Python', 'React', 'Angular2+']",
#        "['Python', 'Django', 'MySQL', 'Docker', 'PHP', 'Kubernetes']",
#        "['NodeJS', 'JavaScript', 'Python', 'React', 'TypeScript']",
#        "['AWS', 'Docker', 'Kubernetes', 'Terraform', 'Helm', 'Python', 'JavaScript']",
#        "['Ruby on Rails', 'PostgreSQL', 'Git', 'Redis', 'MongoDB']",
#        "['PowerShell', 'Zabbix', 'Prometheus', 'Grafana', 'Docker', 'Azure', 'Kubernetes']",
#        "['VMWare', 'Microsoft Office 365', 'SQLServer', 'Microsoft']",
#        "['Python', 'Django', 'AWS']",
#        "['Python', 'PyTorch', 'AWS', 'OpenCV', 'Elasticsearch']",
#        "['Ruby', 'Python', 'JavaScript', 'React', 'PostgreSQL']",
#        "['Android', 'Kotlin', 'Dagger2', 'Figma']",
#        "['Jmeter', 'Selenium', 'Specflow', '.NET']",
#        "['Java', 'JavaScript', 'React', 'Spring']",
#        "['Python', 'Fastapi', 'Flask', 'Github Actions', 'Docker']",
#        "['Python', 'PostgreSQL', 'AWS']",
#        "['AWS', 'Terraform', 'Kubernetes', 'Linux', 'Prometheus', 'Ansible', 'Docker']",
#        "['Kafka', 'AWS', 'Ruby on Rails']",
#        "['NodeJS', 'AWS', 'Docker', 'Nest']",
#        "['React', 'Python', 'Java', 'NodeJS']",
#        "['JavaScript', 'React', 'Redux', 'Python']",
#        "['PHP', 'Symfony', 'AWS', 'Python', 'NodeJS']",
#        "['Golang', 'Rust']",
#        "['AWS', 'Terraform', 'Kubernetes', 'Python']",
#        "['Kubernetes', 'Terraform', 'Google Cloud', 'Redis', 'PostgreSQL', 'Ruby on Rails', 'NodeJS']",
#        "['Java', 'Spring', 'NodeJS', 'Windows', 'AngularJS', 'Salesforce']",
#        "['Elixir', 'PostgreSQL', 'Docker', 'Google Cloud']",
#        "['Ionic', 'Angular2+']",
#        "['Figma', 'Jira', 'Adobe Illustrator', 'Adobe Premiere Pro']",
#        "['Angular2+', 'JavaScript', 'NodeJS']",
#        "['Java', 'Spring Boot', 'Git', 'SQLServer', 'PostgreSQL', 'Angular2+', 'NodeJS']",
#        "['Kotlin', 'Android']",
#        "['PHP', 'Laravel', 'PostgreSQL', 'MySQL', 'HTML', 'JavaScript', 'CSS']",
#        "['Swift', 'Kotlin', 'Viper', 'MVVM', 'Vue', 'NodeJS']",
#        "['NodeJS', 'MongoDB', 'AWS']", "['Airtable', 'CRM']",
#        "['PHP', 'PostgreSQL', 'Symfony', 'YAML', 'PHPunit']",
#        "['Kubernetes', 'AWS', 'Azure', 'Github Actions', 'Datadog', 'Kafka', 'Helm']",
#        "['Ruby on Rails', 'Ruby', 'PostgreSQL', 'AWS']",
#        "['Python', 'SQL', 'Airflow', 'Google Cloud']",
#        "['CSS', 'HTML', 'Figma', 'Magento']",
#        "['WordPress', 'Asana', 'Google Analytics']",
#        "['Java', 'SQL', 'NoSQL', 'RedHat', 'AWS', 'PHP']",
#        "['C#', 'Specflow', 'Selenium', 'SQLServer', 'AngularJS']",
#        "['Docker', 'REST', 'SQL', 'Kafka', 'Kubernetes']",
#        "['C++', 'TypeScript']",
#        "['NodeJS', 'TypeScript', 'PostgreSQL', 'React', 'Golang']",
#        "['Python', 'Django', 'RabbitMQ', 'Docker', 'Fastapi', 'Kubernetes', 'Azure']",
#        "['C++', 'Python', 'AWS']",
#        "['Java', 'Spring', 'AngularJS', 'KendoUI', 'AWS']",
#        "['React', 'NextJS', 'NodeJS', 'MongoDB', 'Vue']",
#        "['Ruby', 'React', 'AWS']",
#        "['Google Cloud', 'Docker', 'Ansible', 'Terraform', 'Python', 'Jenkins', 'Kubernetes']",
#        "['Figma', 'Adobe Photoshop', 'Adobe Illustrator', 'Miro', 'Jira', 'Confluence']",
#        "['Figma', 'Adobe Suit']",
#        "['TypeScript', 'JavaScript', 'React', 'NextJS', 'Apollo', 'Figma']",
#        "['.NET', 'C#', 'PostgreSQL', 'RabbitMQ']",
#        "['PHP', 'WordPress', 'WooCommerce', 'PHPunit', 'Docker', 'React']",
#        "['JavaScript', 'Vue']",
#        "['Java', 'PostgreSQL', 'Docker', 'Spring']",
#        "['React', 'CSS', 'HTML', 'Figma']",
#        "['MySQL', 'MariaDB', 'PHP', 'Java', 'Python', 'TestNg']",
#        "['React', 'Symfony', 'MySQL', 'SQLServer', 'AWS', 'Jenkins']",
#        "['Jira', 'Notion']",
#        "['.NET', 'JavaScript', 'Angular2+', 'Oracle', 'PostgreSQL']",
#        "['CSS', 'HTML', 'JavaScript', 'Vue', 'Python', 'Git', 'PostgreSQL', 'Django']",
#        "['Linux', 'Windows', 'Apple macOS', 'AWS', 'Microsoft Active Directory', 'API']",
#        "['Kubernetes', 'AWS', 'Azure', 'Go']",
#        "['Docker', 'REST', 'Kafka', 'Kubernetes']",
#        "['HTML', 'Python', 'Jenkins', 'React', 'PostgreSQL', 'C++', 'Go']",
#        "['Docker', 'Kubernetes', 'Google Cloud', 'PostgreSQL', 'Ruby on Rails', 'Python']",
#        "['C++']",
#        "['PHP', 'Angular2+', 'MySQL', 'Symfony', 'Docker', 'Kubernetes', 'AWS']",
#        "['Java', 'Kotlin', 'MVVM', 'C++', 'C']",
#        "['.NET', '.Net Core', 'C#', 'CSS', 'Razor', 'Angular2+']",
#        "['Python', 'C++', 'C#']",
#        "['Python', 'Django', 'Elasticsearch', 'Cassandra', 'JavaScript']",
#        "['JavaScript', 'NodeJS', 'MongoDB', 'PostgreSQL', 'AWS', 'Python']",
#        "['PHP', 'Symfony', 'AWS', 'JavaScript']", "['PHP', 'Drupal']",
#        "['Java', 'Spring', 'AWS', 'Elasticsearch', 'AWS Lambda']",
#        "['HTML', 'CSS', 'JavaScript', 'React', 'NextJS', 'Angular2+', 'Vue']",
#        "['AWS', 'Docker', 'Kubernetes', 'Terraform', 'Ansible', 'Python']",
#        "['PHP', 'MySQL', 'Symfony', 'Laravel', 'Redis', 'AWS']",
#        "['Spring Boot', 'Java', 'MongoDB', 'AWS', 'Angular2+']",
#        "['AngularJS', 'TypeScript', 'RxJS', 'CSS', 'NodeJS', 'Webpack', 'Bootstrap']",
#        "['C#', '.NET', 'SQL', 'Azure', 'React', 'JavaScript']",
#        "['Python', 'Kubernetes', 'Terraform', 'NodeJS', 'AWS', 'MongoDB']",
#        "['JavaScript', 'NodeJS', 'Express', 'TypeScript', 'Jest', 'Cypress', 'React', 'AWS']",
#        "['Ruby on Rails', 'JavaScript', 'Elixir', 'Scala', 'Python']",
#        "['PHP', 'Symfony', 'MySQL', 'Docker', 'Angular2+', 'Golang', 'Python']",
#        "['Python']", "['AWS', 'Python', 'Scala']",
#        "['React Native', 'React', 'Redux', 'CSS', 'HTML', 'TypeScript', 'Figma', 'NodeJS']",
#        "['CSS', 'HTML', 'JavaScript', 'React', 'Figma', 'Angular2+', 'Vue', 'Webpack']",
#        "['SQL', 'AWS', 'NodeJS', 'React']", "['C#', 'SQL', 'AngularJS']",
#        "['AWS', 'MongoDB', 'Terraform', 'Kubernetes', 'Bash', 'Python']",
#        "['React', 'React Native', 'TypeScript', 'NodeJS']",
#        "['JavaScript', 'NodeJS', 'MongoDB', 'MySQL', 'Zapier', 'Airtable']",
#        "['AWS', 'Linux', 'data-lake']", "['C++', 'Linux']",
#        "['SQL', 'Python']",
#        "['HTML', 'CSS', 'JavaScript', 'React', 'Vue', 'GraphQL', 'Webpack', 'React Native']",
#        "['Kubernetes', 'AWS', 'Google Cloud', 'Docker', 'Linux', 'Jenkins', 'Prometheus']",
#        "['Python', 'AWS', 'Scala', 'Spark']",
#        "['Java', 'Spring Boot', 'Maven', 'postgres', 'Jenkins', 'rabbit', 'Docker', 'AWS', 'Python']",
#        "['.NET', 'C#', 'MySQL', 'javacript', 'MongoDB']",
#        "['Python', 'Elasticsearch', 'Google Cloud', 'Django']",
#        "['NodeJS', 'Express', 'Jenkins', 'PostgreSQL', 'React']",
#        "['Java', 'Docker', 'AWS', 'JavaScript', 'Kotlin', 'Go']",
#        "['Python', 'PostgreSQL', 'Kafka', 'AWS']",
#        "['PHP', 'JavaScript', 'Symfony', 'React', 'Docker', 'Kubernetes', 'NodeJS']",
#        "['React', 'HTML', 'CSS', 'TypeScript', 'Redux', 'Jest']",
#        "['PHP', 'NodeJS', 'SQL', 'HTML', 'CSS', 'Salesforce']",
#        "['PHP', 'Laravel', 'SQL', 'Vue', 'Angular2+', 'React', 'Docker']",
#        "['Java', 'Spring Boot', 'Google Cloud']",
#        "['Java', 'Python', 'Google Cloud', 'React', 'NodeJS']",
#        "['Android', 'Kotlin', 'Apple iOS', 'Swift']",
#        "['Unity3D', 'C#', 'Jenkins']",
#        "['Java', 'Kotlin', 'AWS', 'Spring Boot', 'Elasticsearch', 'Kafka']",
#        "['Java', 'Spring', 'AWS']",
#        "['JavaScript', 'Kubernetes', 'Java', 'Python', 'Angular2+', 'MongoDB', 'MySQL']",
#        "['Java', 'Spring', 'AWS', 'Angular2+', 'KendoUI']",
#        "['JavaScript', 'React', 'PHP', 'Docker', 'Kubernetes', 'NodeJS']",
#        "['Java', 'Spring', 'PostgreSQL', 'RabbitMQ', 'Docker', 'AWS', 'Elasticsearch', 'Kubernetes']",
#        "['Angular2+', 'TypeScript', 'CSS', 'HTML', 'AWS', 'Docker', 'Jenkins', 'NodeJS', 'Express', 'MongoDB']",
#        "['JavaScript', 'MongoDB', 'React', 'Express', 'NodeJS']",
#        "['HTML', 'JavaScript', 'CSS', 'React']",
#        "['JavaScript', 'NodeJS', 'Express', 'TypeScript', 'React', 'AWS', 'Jest', 'Cypress']",
#        "['CSS', 'HTML', 'JavaScript', 'Figma', 'React']",
#        "['AWS', 'Chef', 'Linux', 'Terraform', 'PostgreSQL', 'Ruby on Rails', 'NodeJS']",
#        "['Java', 'Spring', 'Kubernetes', 'AWS', 'Docker']",
#        "['JavaScript', 'React', 'Redux', 'CSS']",
#        "['Java', 'Kotlin', 'AWS', 'Spring Boot', 'Elasticsearch']",
#        "['JavaScript', 'TypeScript', 'HTML', 'CSS', 'Angular2+', 'Vue', 'React']",
#        "['React', 'CSS', 'TypeScript', 'JavaScript', 'Redux', 'HTML', 'Docker', 'PostgreSQL']",
#        "['JavaScript', 'Vue', 'CSS', 'Angular2+', 'Cordova', '.NET']",
#        "['NodeJS']", "['JavaScript', 'Jenkins', 'Flutter']",
#        "['JavaScript', 'CSS', 'HTML', 'Vue', 'Webpack', 'React', 'Angular2+', 'Sketch', 'Invision', 'Salesforce']",
#        "['Python', 'PostgreSQL', 'Docker', 'Google Cloud', 'Kubernetes']",
#        "['JavaScript', 'Go', 'TypeScript', 'React', 'PostgreSQL']",
#        "['.NET', 'C#', 'CSS', 'Razor', 'Angular2+']",
#        "['Ruby on Rails', 'MySQL', 'Elasticsearch']",
#        "['Figma', 'HTML', 'CSS']",
#        "['JavaScript', 'TypeScript', 'React', 'NodeJS']",
#        "['React', 'JavaScript', 'NodeJS', 'Docker', 'MongoDB']",
#        "['Java', 'Spring', 'Linux', 'Python', 'Docker']",
#        "['Apple iOS', 'Swift', 'Objective-C']",
#        "['Symfony', 'Vue', 'PHP', 'Docker']",
#        "['PHP', 'Laravel', 'Symfony', 'RabbitMQ', 'MongoDB', 'PostgreSQL']",
#        "['React Native', 'CSS', 'Redux', 'Apple iOS', 'Android']",
#        "['Linux', 'Nginx', 'Elasticsearch', 'MySQL', 'PostgreSQL', 'Ansible', 'AWS', 'Apache', 'Terraform', 'Chef']",
#        "['Ruby on Rails', 'Java', 'Python', 'MySQL', 'AWS', 'Angular2+']",
#        "['AWS', 'Kubernetes', 'Terraform']",
#        "['JavaScript', 'SQL', 'CSS', 'HTML', 'Vue', 'PostgreSQL']",
#        "['Java', 'Kafka', 'Elasticsearch', 'Jenkins', 'Kubernetes', 'NodeJS']",
#        "['.NET', 'SQL', 'Git', 'API', 'Azure DevOps', 'Angular2+']",
#        "['Python', 'AWS', 'Airflow', 'MLflow', 'TensorFlow', 'PyTorch', 'Microsoft Power BI']",
#        "['Windows', 'VMWare', 'Microsoft Active Directory', 'Microsoft Office 365', 'AWS', 'Linux', 'SAP']",
#        "['Angular2+', 'NodeJS', 'SQL', 'nestJS', 'Azure']",
#        "['HTML', 'CSS', 'WordPress', 'WebComponents', 'Storybook', 'Figma']",
#        "['HTML', 'CSS', 'JavaScript', 'Shopify', 'PHP']",
#        "['Android', 'Kotlin', 'Dagger2', 'Coroutines', 'Figma']",
#        "['PHP', 'JavaScript', 'Symfony', 'Kubernetes', 'Vue', 'AWS']",
#        "['React', 'NextJS', 'TypeScript', 'NodeJS', 'Figma', 'AWS']",
#        "['VanillaJS', 'CSS', 'Github', 'React', 'Shopify', 'jQuery', 'PHP', 'Remix']",
#        "['Nest', 'NodeJS', 'React', 'AWS', 'NextJS', 'React Native', 'Ethereum', 'Solidity', 'Github Actions']",
#        "['CRM', 'Canva', 'Trello', 'Google Analytics', 'Adobe Photoshop', 'Adobe Illustrator', 'WordPress']",
#        "['Figma', 'Sketch', 'Adobe Xd', 'Miro', 'Hotjar', 'LookBack', 'Maze']",
#        "['TypeScript', 'nestJS', 'Vue', 'AWS', 'MQTT', 'Docker', 'Kubernetes']",
#        "['PyTorch', 'TensorFlow', 'Apache', 'Airflow', 'Pandas', 'Docker', 'Kubernetes']",
#        "['PostgreSQL']",
#        "['Java', 'Spring Boot', 'Kubernetes', 'Go', 'AWS', 'Azure', 'React', 'Angular2+', 'Vue']",
#        "['C', 'Linux', 'Python', 'Git', 'Golang', 'Docker', 'Rust', 'GitLab']",
#        "['React', 'NextJS', 'Tailwind', 'AWS', 'Azure']",
#        "['.NET', 'JavaScript', 'Angular2+', 'React', 'Python', 'Docker', 'GitLab']",
#        "['NodeJS', 'JavaScript', 'PHP', 'Symfony', 'Vue']",
#        "['NextJS', 'CSS', 'TypeScript', 'JavaScript', 'Redux', 'HTML', 'Docker', 'PostgreSQL']",
#        "['Selenium', 'Cypress', 'JUnit', '.NET']",
#        "['Kotlin', 'Spring Boot', 'Kafka', 'RabbitMQ', 'ETL']",
#        "['JavaScript', 'Flutter', 'Vue', 'GraphQL', 'React', 'React Native']",
#        "['PostgreSQL', 'C#', 'API', 'AWS', 'Docker']",
#        "['Docker', 'SQLServer', 'PowerShell', 'IIS', 'Kubernetes', 'Pulumi', 'Azure DevOps', 'Azure', 'Jenkins']",
#        "['Tableau', 'Microsoft Power BI', 'SQL']",
#        "['PySpark', 'SQL', 'Python', 'AWS Lambda', 'Github', 'AWS', 'S3', 'Docker', 'ETL']",
#        "['C++', 'CMake', 'Git', 'Qt', 'OpenGL']",
#        "['Figma', 'CSS', 'HTML', 'JavaScript']",
#        "['AWS', 'Docker', 'Python', 'Terraform', 'Grafana', 'ELK']",
#        "['SaaS', 'CRM', 'PowerShell']",
#        "['JavaScript', 'Vue', 'Angular2+', 'React', 'Figma', 'Tailwind']",
#        "['PHP', 'MySQL', 'Laravel', 'JavaScript', 'CSS', 'HTML', 'PostgreSQL', 'Angular2+']",
#        "['Python', 'SQL', 'Pandas', 'BigQuery', 'Django', 'HTML', 'CSS', 'JavaScript']",
#        "['Vue', 'Jest', 'TypeScript', 'Vitest', 'TestingLibrary', 'Tailwind', 'React']",
#        "['JavaScript', 'React', 'NodeJS', 'NextJS', 'AWS', 'Azure', 'Ethereum', 'Web3']",
#        "['AWS', 'Kubernetes', 'Terraform', 'Helm', 'Datadog', 'Kong', 'Go']",
#        "['Python', 'AWS', 'SQL', 'Redshift', 'Snowflake']",
#        "['NextJS', 'TypeScript', 'React', 'Webpack', 'Git', 'Docker']",
#        "['Java', '.NET', 'PHP', 'Dart', 'Flutter']",
#        "['C++', 'C', 'Rust']",
#        "['Python', 'Fastapi', 'TypeScript', 'HTML', 'CSS', 'Docker', 'Jenkins', 'RabbitMQ', 'React']",
#        "['PHP', 'Symfony', 'Vuex', 'JavaScript', 'MySQL', 'VanillaJS']",
#        "['Java', 'Spring Boot', 'Hibernate', 'RabbitMQ', 'Kafka', 'AWS', 'Angular2+']",
#        "['Java', 'Kubernetes', 'OpenShift', 'Git', 'Kafka', 'MongoDB', 'SQL', 'Hazelcast']",
#        "['NodeJS', 'JavaScript', 'MySQL', 'MongoDB', 'NextJS', 'React', 'React Native']",
#        "['PHP', 'API', 'PHPunit', 'Cypress']", "['Flutter']",
#        "['Docker', 'AWS', 'Linux', 'Terraform', 'Zabbix', 'Python', 'Java']",
#        "['PHP', 'Laravel', 'WordPress', 'API', 'Symfony']", "['DB2']",
#        "['Python', 'Spark', 'SQL', 'AWS', 'Google Looker Studio']",
#        "['Python', 'Django', 'Kubernetes', 'React', 'Google Cloud']",
#        "['SQL', 'Python', 'dbt', 'PowerCenter', 'Microsoft SQL Integration Services (SSIS)', 'SaaS']",
#        "['Angular2+', 'CSS', 'Ionic', 'C#', 'MongoDB']",
#        "['Linux', 'Ansible', 'Python', 'JavaScript']",
#        "['PHP', 'MySQL', 'Symfony', 'CodeIgniter', 'MongoDB']",
#        "['.NET', 'C#', 'Azure', 'SQLServer', 'Python']",
#        "['Azure', 'AWS', 'OpenStack', 'Prometheus', 'Python', 'MySQL', 'PostgreSQL']",
#        "['AWS', '.NET', 'Terraform']",
#        "['JavaScript', 'HTML', 'CSS', 'React', 'Figma']",
#        "['Ruby on Rails', 'PostgreSQL', 'MongoDB', 'Redis', 'Kubernetes']",
#        "['PHP', 'Git', 'Docker', 'API', 'Magento', 'Shopify']",
#        "['Java', 'Spring Boot', 'MySQL', 'MongoDB', 'Kubernetes', 'AWS']",
#        "['AngularJS', 'TypeScript', 'Ionic', 'Git']",
#        "['Google Cloud', 'Terraform', 'Kubernetes', 'Python']",
#        "['TypeScript', 'Jest', 'React Native', 'Kotlin', 'Swift', 'Viper', 'Android', 'Flutter']",
#        "['React', 'Redux', 'WebSockets', 'Jest', 'Mocha', 'NextJS', 'Cypress']",
#        "['Ruby on Rails', 'MySQL', 'Elasticsearch', 'JavaScript', 'SaaS']",
#        "['Java', 'AWS', 'Kotlin', 'Groovy', 'MySQL', 'Elasticsearch']",
#        "['OpenCV', 'Python', 'TensorFlow', 'PyTorch', 'R', 'AWS']",
#        "['SQL', 'Python', 'Java', 'Kafka', 'Snowflake', 'BigQuery', 'dbt']",
#        "['Android', 'Kotlin', 'Swift']", "['SQL', 'SQLServer', 'Azure']",
#        "['Android', 'Java', 'Kotlin', 'Flutter', 'Swift']",
#        "['.NET', 'ASP.net', 'MySQL', 'DynamoDB', 'Docker', 'AWS']",
#        "['JavaScript', 'React', 'NodeJS', 'AWS', 'Azure', 'Ethereum', 'Web3']",
#        "['Python', 'SQL', 'AWS', 'MongoDB', 'Github Actions', 'Docker']",
#        "['PHP', 'Docker', 'AWS', 'Drupal', 'React Native']",
#        "['Symfony', 'PHP', 'MySQL', 'Docker', 'Vagrant', 'HTML', 'CSS', 'JavaScript']",
#        "['C', 'C++', 'Zoho', 'Fortran']",
#        "['Azure', 'Python', 'TypeScript', 'React']",
#        "['Java', 'AWS', 'Spring', 'Hibernate', 'NodeJS', 'Kafka', 'Kotlin']",
#        "['PHP', 'Symfony', 'SQL', 'Git', 'Shopify', 'WooCommerce']",
#        "['JavaScript', 'React', 'Tailwind', 'Docker', 'WebComponents']",
#        "['React', 'TypeScript', 'CSS', 'NextJS', 'React Native']",
#        "['Microsoft', 'Microsoft Active Directory']",
#        "['JavaScript', 'TypeScript', 'HTML', 'CSS', 'Java']", "['Cisco']",
#        "['Go', 'Ruby', 'Elixir']",
#        "['Angular2+', 'JavaScript', 'Fastapi', 'Python', 'MongoDB']",
#        "['Java', 'Spring Boot', 'AWS', 'NodeJS', 'Angular2+']",
#        "['Ruby', 'PostgreSQL', 'Elasticsearch', 'JavaScript', 'CSS']",
#        "['R', 'SQLServer', 'AWS', 'Docker', 'Python', 'Airflow', 'Snowflake']",
#        "['AWS', 'SQL']",
#        "['React Native', 'React', 'TypeScript', 'JavaScript', 'Docker']",
#        "['Atlassian', 'Jira', 'Confluence']",
#        "['PostgreSQL', 'SQL', 'AWS']",
#        "['JavaScript', 'Angular2+', 'Vue', 'Docker', 'Figma', 'Magento']",
#        "['PHP', 'MySQL', 'HTML', 'CSS', 'AJAX', 'jQuery']",
#        "['AWS', 'Kubernetes', 'Docker', 'Terraform', 'Prometheus', 'PostgreSQL', 'Python', 'Ansible']",
#        "['Ruby on Rails', 'Java', 'PHP', 'JavaScript', 'React', 'Python']",
#        "['AWS', 'Python', 'Django', 'Flask', 'Docker', 'Jenkins']",
#        "['Java', 'Spring Boot', 'Git', 'MySQL']",
#        "['JavaScript', 'HTML', 'CSS', 'Figma', 'React', 'Google Analytics']",
#        "['Jenkins', 'Linux', 'PowerShell', 'AWS']",
#        "['Python', 'Django', 'Fastapi', 'SQL', 'AWS']",
#        "['InfluxDB', 'Kafka', 'RabbitMQ', 'Flink', 'Airflow']",
#        "['Python', 'Django', 'API', 'SQL', 'AWS']",
#        "['Golang', 'AWS', 'TypeScript', 'NodeJS', 'React', 'NextJS']",
#        "['.NET', 'C#', 'Git', 'Selenium', 'SQL', 'Java', 'JavaScript']",
#        "['Figma', 'CSS', 'HTML', 'JavaScript', 'Microsoft Office 365', 'Adobe Xd', 'Microsoft Dynamics 365', 'Microsoft Power BI']",
#        "['JavaScript', 'NodeJS', 'MongoDB', 'PostgreSQL', 'TypeScript']",
#        "['Python', 'Django', 'Git', 'SQL', 'Bootstrap', 'Vue', 'Pytest', 'AWS', 'Github']",
#        "['AWS', 'Docker', 'Kubernetes', 'Terraform', 'Helm']",
#        "['TypeScript', 'SQL', 'Jest', 'nestJS', 'NodeJS', 'ELK']",
#        "['Vue', 'Jest', 'TypeScript', 'TestingLibrary', 'React', 'Tailwind']",
#        "['React', 'JavaScript', 'HTML', 'CSS', 'GraphQL', 'Docker']",
#        "['Python', 'AWS']",
#        "['JavaScript', 'Python', 'NoSQL', 'Cypress']",
#        "['SQL', 'Python', 'BigQuery', 'Google Looker Studio', 'dbt']",
#        "['AWS', 'Terraform', 'Kubernetes', 'Docker', 'Helm', 'Prometheus', 'Grafana']",
#        "['SQLServer']",
#        "['React Native', 'TypeScript', 'React', 'Figma', 'HTML', 'CSS']",
#        "['.NET', 'SQLServer', 'C#', '.Net Core', 'Azure', 'Blazor', 'JavaScript', 'CSS', 'Vue']",
#        "['Asana', 'Trello']",
#        "['Java', 'Spring Boot', 'REST', 'PostgreSQL', 'Docker', 'ActiveMQ', 'SOAP', 'Kubernetes', 'Angular2+']",
#        "['Drupal', 'PHP', 'MySQL', 'Git']",
#        "['Kubernetes', 'Docker', 'Terraform', 'AWS', 'Google Cloud', 'Python']",
#        "['Kotlin', 'Android', 'Java']",
#        "['JavaScript', 'React', 'CSS', 'HTML', 'REST', 'Cypress']",
#        "['NodeJS', 'MongoDB', 'Vue']", "['CSS', 'HTML', 'JavaScript']",
#        "['Python', 'Django', 'Docker', 'Fastapi']",
#        "['Google Firebase', 'Google Analytics']",
#        "['Go', 'TypeScript', 'PHP', 'AWS', 'Laravel', 'Vue']",
#        "['Java', 'AWS', 'React', 'Ruby', 'Kotlin', 'Python']",
#        "['Angular2+', 'openlayers', 'CARTO', 'ArcGIS', 'Leaflet', 'Geoserver']",
#        "['NodeJS', 'NextJS', 'MongoDB', 'TypeScript', 'React', 'Github Actions']",
#        "['NodeJS', 'AWS', 'Docker', 'Nest', 'Terraform']",
#        "['AWS', 'Jenkins', 'Docker', 'Elasticsearch', 'Kafka', 'Grafana']",
#        "['NodeJS', 'SQL', 'React', 'AWS Lambda', 'AWS']",
#        "['JavaScript', 'NodeJS', 'Express', 'MongoDB', 'AWS', 'React']",
#        "['React', 'React Native', 'HTML', 'Figma', 'CSS']",
#        "['Python', 'Git', 'GitLab', 'SQL', 'NoSQL', 'Kubernetes', 'Docker', 'AWS']",
#        "['Java', 'Spring', 'AWS', 'Angular2+']",
#        "['SQL', 'C#', '.Net Core', 'SQLServer', 'Vue', '.NET', 'Kubernetes', 'Azure', 'TypeScript']",
#        "['SQL', 'Python', 'Google Looker Studio']",
#        "['Docker', 'Kubernetes', 'Azure', 'Terraform', 'Grafana', 'Prometheus']",
#        "['JavaScript', 'CSS', 'Vue', 'Tailwind', 'Figma', 'Cypress', 'Laravel']",
#        "['HTML', 'CSS', 'JavaScript', 'React', 'Vue', 'AWS', 'Docker']",
#        "['PHP', 'MySQL', 'Docker']", "['JavaScript', 'NodeJS', 'NextJS']",
#        "['Java', 'Android', 'Kotlin']",
#        "['PHP', 'MySQL', 'AWS', 'JavaScript', 'HTML', 'React']",
#        "['Android', 'Apple iOS', 'Git']",
#        "['JavaScript', 'Docker', 'Vue', 'Angular2+', 'Figma', 'Tailwind']",
#        "['Swift']", "['Python', 'PyTorch', 'TensorFlow', 'OpenCV']",
#        "['NodeJS', 'Google Firebase', 'Google Cloud', 'NoSQL', 'Jira']",
#        "['.NET', '.Net Core', 'C#', 'HTML']",
#        "['Java', 'Spark', 'Elasticsearch', 'Lucene', 'AWS']",
#        "['JavaScript', 'HTML', 'CSS', 'React', 'Ruby on Rails', 'AWS']",
#        "['JavaScript', 'Go', 'SQL', 'Tableau', 'Snowflake']",
#        "['REST', 'Go', 'Java', 'TypeScript', 'React']",
#        "['Linux', 'AWS', 'Bash', 'Docker', 'Kubernetes']",
#        "['React', 'TypeScript', 'Cypress', 'Jest', 'Amplitude', 'Segment']",
#        "['Swift', 'Objective-C', 'UIKit']",
#        "['Android', 'Kotlin', 'Flutter', 'Git']",
#        "['MongoDB', 'TypeScript', 'JavaScript', 'NodeJS', 'React', 'React Native', 'C++', 'Python']",
#        "['PHP', 'Symfony', 'SQL', 'NoSQL', 'Docker']",
#        "['Python', 'AWS', 'Spark', 'Airflow', 'Terraform', 'Elasticsearch']",
#        "['Go', 'Docker']",
#        "['PHP', 'MySQL', 'Jenkins', 'Symfony', 'Spring', 'Java', 'JavaScript', 'AWS']",
#        "['Docker', 'Linux', 'Terraform', 'Java', 'Zabbix', 'Python', 'AWS']",
#        "['AWS', 'Git', 'GitLab', 'Linux', 'Azure', 'Google Cloud', 'Terraform']",
#        "['JavaScript', 'TypeScript', 'CSS', 'React', 'AngularJS', 'Redux', 'Bootstrap']",
#        "['Angular2+', 'JavaScript', 'Vue', 'React', 'Oracle', 'PostgreSQL']",
#        "['Java', 'Jenkins', 'Cucumber', 'Selenium', 'Appium', 'Postman', 'JavaScript', 'Cypress', 'Karate', 'PACT', 'Docker']",
#        "['Hubspot', 'Google Analytics', 'Google Ads', 'Facebook Ads', 'Linkedin Ads', 'Hotjar', 'Google Optimize', 'Figma', 'Canva']",
#        "['Python', 'AWS', 'DynamoDB', 'Redis']",
#        "['PHP', 'MySQL', 'C++', 'Docker', 'Kubernetes']",
#        "['JavaScript', 'SQL', 'Ruby', 'HTML', 'CSS', 'AWS']",
#        "['Microsoft Dynamics 365', 'Microsoft Office 365']",
#        "['Java', 'Spring', 'AWS', 'Jenkins', 'JavaScript', 'PostgreSQL']",
#        "['Python', 'PHP', 'MySQL', 'AWS', 'Git', 'Redis', 'Kafka', 'Linux', 'Jenkins', 'C']",
#        "['SQL']", "['Elixir', 'PHP', 'React', 'AWS']",
#        "['Jmeter', 'Java', 'Grafana', 'AWS']",
#        "['CSS', 'HTML', 'JavaScript', 'Storybook', 'Figma', 'React']",
#        "['SQL', 'Python', 'Snowflake', 'BigQuery']",
#        "['AWS', 'VMWare', 'Docker', 'Kubernetes', 'Terraform', 'Bitbucket', 'Jenkins']",
#        "['JavaScript', 'React', 'CSS', 'HTML', 'Figma', 'TypeScript', 'Redux']",
#        "['Docker', 'Kubernetes', 'Terraform', 'Google Cloud', 'PostgreSQL']",
#        "['Python', 'MongoDB', 'AWS']",
#        "['Java', 'Spring Boot', 'Git', 'SQLServer', 'MongoDB', 'Angular2+', 'NodeJS']",
#        "['NodeJS', 'Express', 'MongoDB']",
#        "['PHP', 'MySQL', 'Git', 'Linux', 'Vue']",
#        "['SQL', 'Google Looker Studio', 'Python']",
#        "['JavaScript', 'CSS', 'HTML', 'NodeJS', 'TypeScript']",
#        "['PHP', 'MySQL', 'Symfony', 'JavaScript', 'CSS', 'AWS', 'Zend']",
#        "['Selenium', 'Python']",
#        "['Java', 'Spring Boot', 'MySQL', 'Docker', 'AWS', 'Serverless']",
#        "['Vue', 'React', 'AngularJS', 'AWS', 'PHP']",
#        "['Python', 'Airflow', 'AWS']", "['Java', 'AWS', 'Vue']",
#        "['Java', 'Spring', 'Angular2+', 'MySQL', 'MongoDB', 'Docker', 'NodeJS', 'Kubernetes', 'OpenShift']",
#        "['AWS', 'Docker', 'Kubernetes', 'Terraform', 'PHP']",
#        "['JavaScript', 'HTML', 'Google Tag Manager', 'Google Analytics', 'Google Data Studio', 'Google Cloud', 'Microsoft Excel', 'Salesforce']",
#        "['Python', 'PostgreSQL', 'Django', 'Linux', 'GraphQL']",
#        "['.NET']",
#        "['BigQuery', 'Airflow', 'Python', 'Spark', 'AWS', 'Google Cloud', 'Docker', 'Kubernetes']",
#        "['Python', 'Django', 'JavaScript', 'React']",
#        "['Java', 'Spring Boot', 'Kotlin', 'Kafka', 'AWS', 'Kubernetes']",
#        "['AWS']", "['Python', 'SQL', 'Spark', 'AWS']",
#        "['CSS', 'HTML', 'JavaScript', 'React', 'Figma', 'Vue']",
#        "['JavaScript', 'TypeScript', 'Angular2+', 'React', 'Vue', 'PHP', 'Redux']",
#        "['JavaScript', 'React', 'AngularJS', 'Vue', 'TypeScript', 'Redux', 'Flutter', 'React Native']",
#        "['.NET', 'C#', 'MySQL', 'MongoDB', 'JavaScript']",
#        "['Java', 'Spring', 'SQL', 'shell-scripting', 'Jenkins']",
#        "['Linux', 'Jenkins', 'Bash', 'Apache', 'Nginx', 'Apache Tomcat', 'git-bash']",
#        "['javacript', 'CSS', 'HTML', 'React', 'NodeJS', 'Vue']",
#        "['Apple iOS', 'Swift', 'AWS', 'Python']",
#        "['TypeScript', 'NodeJS', 'MongoDB', 'React', 'TensorFlow', 'Python']",
#        "['Kotlin', 'Swift', 'reactive-programming']",
#        "['JavaScript', 'TypeScript', 'AngularJS', 'React']",
#        "['Linux', 'MySQL', 'Jenkins', 'PHP']",
#        "['JavaScript', 'TypeScript', 'Cypress', 'Angular2+', 'React', 'Vue', 'Java']",
#        "['Docker', 'Linux', 'AWS', 'Azure', 'Google Cloud', 'Elasticsearch', 'Kubernetes', 'Ansible', 'Terraform']",
#        "['Python', 'Django']",
#        "['Java', 'Spring Boot', 'MongoDB', 'AngularJS']",
#        "['Django', 'React']",
#        "['Java', 'Kubernetes', 'Docker', 'Azure', 'Google Cloud', 'AWS']",
#        "['React', 'TypeScript', 'HTML', 'CSS', 'NodeJS', 'GraphQL', 'AWS']",
#        "['Linux', 'Docker', 'SQL', 'Ansible', 'Puppet', 'Python', 'AWS']",
#        "['Terraform', 'Docker', 'Kubernetes', 'Jenkins', 'AWS', 'Ansible']",
#        "['Linux', 'MySQL', 'AWS', 'PostgreSQL', 'Google Cloud', 'Elasticsearch', 'Cassandra']",
#        "['Kotlin', 'Swift', 'Apple iOS', 'Sketch', 'Github']",
#        "['C#', '.NET', 'Azure', 'JavaScript', 'SQL', 'Angular2+']",
#        "['Android', 'Kotlin', 'Java', 'Github', '.NET', 'Apple iOS']",
#        "['Spark', 'Scala', 'Kafka', 'AWS', 'TypeScript', 'Java']",
#        "['React', 'HTML', 'CSS', 'JavaScript', 'NodeJS', 'NextJS', 'Jest', 'Cypress']",
#        "['Angular2+', 'CSS', 'HTML', 'C#']",
#        "['React', 'AWS', 'NodeJS', 'SQL']", "['Google Analytics']",
#        "['React', 'TypeScript', 'React Native', 'Java', 'Spring', 'AWS']",
#        "['JavaScript', 'MongoDB', 'React', 'NodeJS', 'AWS', 'Spring']",
#        "['HTML', 'CSS', 'JavaScript', 'Webpack', 'React', 'Figma']",
#        "['NodeJS', '.NET', 'Java', 'PHP', 'React', 'Docker', 'Azure']",
#        "['React', 'React Native', 'MongoDB', 'Google Firebase', 'Rust']",
#        "['Apple iOS', 'Git', 'Swift']",
#        "['Python', 'SQL', 'MongoDB', 'PostgreSQL', 'BigQuery']",
#        "['Python', 'PostgreSQL', 'MongoDB', 'Docker']",
#        "['Figma', 'Sketch']",
#        "['C#', 'SQL', 'HTML', 'CSS', 'Vue', 'Azure', 'Webpack', 'Docker', 'Python']",
#        "['JavaScript', 'React', 'CSS', 'HTML', 'Figma', 'Bootstrap']",
#        "['JavaScript', 'CSS', 'HTML', 'Vue', 'Figma', 'Flutter', 'TypeScript']",
#        "['Flutter', 'Android', 'Apple iOS', 'SQL', 'C++']",
#        "['Python', 'Django', 'PostgreSQL', 'Kubernetes']",
#        "['JavaScript', 'NodeJS', 'SQL', 'Vue', 'Go']",
#        "['Java', 'Spring', 'AWS', 'Azure', 'React', 'Python', 'PostgreSQL']",
#        "['Go', 'React', 'Ruby']",
#        "['.NET', 'C#', 'Docker', 'MySQL', 'AWS']",
#        "['Ruby on Rails', 'JavaScript', 'PostgreSQL', 'NodeJS', 'AWS', 'GraphQL']",
#        "['JavaScript', 'HTML', 'CSS', 'React', 'Vue', 'Java', 'AngularJS']",
#        "['Figma', 'CSS', 'HTML', 'React']",
#        "['Spring', 'Java', 'PostgreSQL', 'AWS']",
#        "['JavaScript', 'HTML', 'CSS', 'Angular2+', 'Ruby on Rails', 'Java', 'Python']",
#        "['Java']",
#        "['PHP', 'MySQL', 'Symfony', 'Laravel', 'Elasticsearch']"],
#       dtype=object)

# %% [markdown]
# #### SKILLS

# %%
df2["skills"].unique()
# Out:
# array(["['Trabajo en equipo', 'Pensamiento analítico', 'Liderazgo', 'Aprendizaje Continuo', 'Adaptabilidad al cambio', 'Proactividad', 'Pensamiento creativo']",
#        "['Adaptabilidad al cambio', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Proactividad']",
#        "['Visión crítica', 'Capacidad de abstracción', 'Trabajo en equipo', 'Atención al detalle', 'Inteligencia emocional', 'Proactividad', 'Aprendizaje Continuo', 'Pensamiento analítico', 'Habilidades de negociación', 'Comunicación intercultural']",
#        "['Atención al detalle', 'Capacidad de dar feedback', 'Trabajo en equipo', 'Proactividad', 'Aprendizaje Continuo', 'Capacidad de autogestión']",
#        "['Aprendizaje Continuo', 'Capacidad de dar feedback', 'Proactividad', 'Trabajo en equipo']",
#        "['Adaptabilidad al cambio', 'Comunicación verbal', 'Gestión de equipo', 'Aprendizaje Continuo', 'Atención al detalle', 'Comunicación escrita', 'Comunicación intercultural']",
#        "['Atención al detalle', 'Trabajo en equipo', 'Comunicación verbal', 'Pensamiento analítico', 'Visión estratégica']",
#        "['Comunicación verbal', 'Trabajo en equipo', 'Comunicación escrita', 'Visión crítica', 'Pensamiento analítico', 'Visión estratégica']",
#        "['Atención al detalle', 'Pensamiento analítico', 'Trabajo en equipo', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Capacidad de mentorización']",
#        "['Adaptabilidad al cambio', 'Comunicación verbal', 'Atención al detalle', 'Trabajo en equipo']",
#        "['Adaptabilidad al cambio', 'Pensamiento analítico', 'Autonomía en el aprendizaje', 'Visión crítica', 'Visión estratégica', 'Liderazgo']",
#        "['Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Comunicación intercultural', 'Comunicación verbal', 'Liderazgo', 'Proactividad']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de autogestión', 'Proactividad', 'Adaptabilidad al cambio', 'Capacidad de dar feedback']",
#        nan,
#        "['Atención al detalle', 'Pensamiento analítico', 'Proactividad', 'Capacidad de mentorización']",
#        "['Atención al detalle', 'Comunicación verbal', 'Trabajo en equipo', 'Capacidad de escucha', 'Aprendizaje Continuo']",
#        "['Adaptabilidad al cambio', 'Proactividad', 'Autonomía en el aprendizaje', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Atención al detalle', 'Capacidad de mentorización']",
#        "['Proactividad', 'Autonomía en el aprendizaje', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de autogestión']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo', 'Resistencia a la frustración', 'Autonomía en el aprendizaje']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Proactividad', 'Pensamiento analítico', 'Atención al detalle', 'Capacidad de autogestión']",
#        "['Comunicación verbal', 'Capacidad de presentación', 'Resistencia a la frustración', 'Pensamiento creativo', 'Proactividad', 'Atención al detalle', 'Capacidad de recibir feedback', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Habilidades de negociación']",
#        "['Trabajo en equipo', 'Adaptabilidad al cambio', 'Comunicación intercultural', 'Aprendizaje Continuo', 'Comunicación verbal', 'Visión crítica']",
#        "['Aprendizaje Continuo', 'Capacidad de autogestión', 'Proactividad', 'Tolerancia a la incertidumbre', 'Trabajo en equipo']",
#        "['Adaptabilidad al cambio', 'Capacidad de autogestión', 'Proactividad', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Atención al detalle', 'Liderazgo', 'Visión estratégica']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Capacidad de dar feedback', 'Trabajo en equipo', 'Comunicación escrita', 'Comunicación verbal', 'Proactividad']",
#        "['Comunicación verbal', 'Gestión de equipo', 'Liderazgo', 'Pensamiento analítico', 'Proactividad', 'Visión estratégica', 'Comunicación escrita', 'Capacidad de dar feedback']",
#        "['Adaptabilidad al cambio', 'Capacidad de autogestión', 'Proactividad', 'Visión crítica', 'Trabajo en equipo', 'Liderazgo', 'Visión estratégica']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Trabajo en equipo']",
#        "['Atención al detalle', 'Capacidad de autogestión', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Visión estratégica']",
#        "['Visión estratégica', 'Liderazgo', 'Proactividad', 'Inteligencia emocional', 'Pensamiento analítico', 'Adaptabilidad al cambio', 'Capacidad de dar feedback']",
#        "['Autonomía en el aprendizaje', 'Atención al detalle', 'Trabajo en equipo', 'Adaptabilidad al cambio', 'Pensamiento analítico', 'Capacidad de autogestión', 'Proactividad']",
#        "['Comunicación verbal', 'Habilidades de negociación', 'Capacidad de escucha', 'Aprendizaje Continuo', 'Capacidad de presentación', 'Capacidad de recibir feedback']",
#        "['Adaptabilidad al cambio', 'Trabajo en equipo', 'Proactividad', 'Resistencia a la frustración', 'Autonomía en el aprendizaje', 'Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de autogestión']",
#        "['Proactividad', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Adaptabilidad al cambio', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Trabajo en equipo']",
#        "['Aprendizaje Continuo', 'Proactividad', 'Trabajo en equipo', 'Atención al detalle', 'Capacidad de autogestión']",
#        "['Trabajo en equipo', 'Proactividad', 'Atención al detalle', 'Comunicación verbal', 'Autonomía en el aprendizaje', 'Aprendizaje Continuo']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de escucha', 'Trabajo en equipo', 'Proactividad', 'Visión estratégica', 'Capacidad de autogestión', 'Comunicación verbal', 'Gestión de equipo']",
#        "['Aprendizaje Continuo', 'Capacidad de autogestión', 'Trabajo en equipo', 'Proactividad', 'Atención al detalle']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo', 'Habilidades de negociación', 'Autonomía en el aprendizaje', 'Proactividad', 'Capacidad de presentación', 'Comunicación verbal']",
#        "['Aprendizaje Continuo', 'Comunicación verbal', 'Trabajo en equipo', 'Proactividad', 'Atención al detalle', 'Pensamiento analítico']",
#        "['Trabajo en equipo', 'Comunicación verbal', 'Comunicación escrita', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Visión crítica']",
#        "['Capacidad de autogestión', 'Proactividad', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Liderazgo', 'Visión estratégica']",
#        "['Proactividad', 'Trabajo en equipo', 'Capacidad de autogestión', 'Autonomía en el aprendizaje', 'Aprendizaje Continuo', 'Atención al detalle']",
#        "['Comunicación escrita', 'Autonomía en el aprendizaje', 'Proactividad', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Comunicación verbal', 'Capacidad de mentorización']",
#        "['Gestión de equipo', 'Liderazgo', 'Habilidades de negociación', 'Trabajo en equipo', 'Proactividad', 'Capacidad de dar feedback', 'Capacidad de escucha', 'Pensamiento creativo', 'Atención al detalle']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Pensamiento analítico', 'Autonomía en el aprendizaje', 'Proactividad', 'Adaptabilidad al cambio', 'Capacidad de recibir feedback']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de autogestión', 'Capacidad de escucha', 'Proactividad', 'Autonomía en el aprendizaje']",
#        "['Liderazgo', 'Capacidad de autogestión', 'Visión crítica', 'Tolerancia a la incertidumbre', 'Proactividad', 'Comunicación verbal', 'Comunicación escrita']",
#        "['Autonomía en el aprendizaje', 'Adaptabilidad al cambio', 'Gestión de equipo', 'Liderazgo', 'Comunicación verbal', 'Visión estratégica', 'Visión crítica']",
#        "['Atención al detalle', 'Autonomía en el aprendizaje', 'Trabajo en equipo', 'Adaptabilidad al cambio', 'Pensamiento analítico', 'Capacidad de autogestión', 'Proactividad']",
#        "['Capacidad de autogestión', 'Aprendizaje Continuo', 'Capacidad de escucha', 'Proactividad', 'Capacidad de mentorización', 'Visión estratégica', 'Liderazgo']",
#        "['Comunicación verbal', 'Comunicación escrita', 'Gestión de equipo', 'Visión estratégica', 'Comunicación intercultural', 'Visión crítica']",
#        "['Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Pensamiento analítico', 'Adaptabilidad al cambio', 'Atención al detalle', 'Proactividad']",
#        "['Atención al detalle', 'Comunicación verbal', 'Proactividad', 'Visión crítica', 'Pensamiento analítico', 'Visión estratégica', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Capacidad de recibir feedback']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Trabajo en equipo']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Atención al detalle', 'Capacidad de recibir feedback', 'Visión crítica', 'Proactividad', 'Trabajo en equipo', 'Pensamiento creativo', 'Pensamiento analítico']",
#        "['Liderazgo', 'Capacidad de mentorización', 'Visión estratégica', 'Trabajo en equipo', 'Visión crítica', 'Comunicación intercultural', 'Capacidad de abstracción', 'Proactividad']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo']",
#        "['Aprendizaje Continuo', 'Comunicación verbal', 'Trabajo en equipo', 'Proactividad', 'Atención al detalle']",
#        "['Atención al detalle', 'Capacidad de autogestión', 'Visión crítica', 'Tolerancia a la incertidumbre', 'Capacidad de abstracción', 'Proactividad', 'Comunicación verbal']",
#        "['Pensamiento analítico', 'Trabajo en equipo', 'Proactividad', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Capacidad de autogestión']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo', 'Autonomía en el aprendizaje', 'Comunicación escrita', 'Comunicación verbal', 'Atención al detalle']",
#        "['Adaptabilidad al cambio', 'Comunicación verbal', 'Visión crítica', 'Aprendizaje Continuo', 'Proactividad', 'Comunicación escrita', 'Capacidad de mentorización']",
#        "['Atención al detalle', 'Capacidad de autogestión', 'Habilidades de negociación', 'Pensamiento analítico', 'Visión estratégica', 'Proactividad', 'Trabajo en equipo', 'Comunicación verbal', 'Liderazgo']",
#        "['Liderazgo', 'Capacidad de mentorización', 'Gestión de equipo', 'Proactividad', 'Capacidad de dar feedback', 'Inteligencia emocional']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo', 'Capacidad de autogestión', 'Autonomía en el aprendizaje']",
#        "['Adaptabilidad al cambio', 'Capacidad de autogestión', 'Trabajo en equipo', 'Proactividad', 'Comunicación intercultural', 'Aprendizaje Continuo', 'Visión estratégica']",
#        "['Proactividad', 'Trabajo en equipo', 'Atención al detalle', 'Aprendizaje Continuo', 'Adaptabilidad al cambio']",
#        "['Comunicación verbal', 'Adaptabilidad al cambio', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Inteligencia emocional', 'Gestión de equipo', 'Capacidad de mentorización']",
#        "['Trabajo en equipo', 'Atención al detalle', 'Aprendizaje Continuo', 'Proactividad', 'Visión crítica']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo', 'Proactividad', 'Comunicación verbal']",
#        "['Capacidad de presentación', 'Comunicación verbal', 'Habilidades de negociación', 'Atención al detalle', 'Capacidad de autogestión', 'Pensamiento analítico', 'Visión estratégica']",
#        "['Capacidad de autogestión', 'Proactividad', 'Aprendizaje Continuo', 'Resistencia a la frustración', 'Adaptabilidad al cambio', 'Comunicación verbal']",
#        "['Capacidad de autogestión', 'Proactividad', 'Comunicación verbal', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Atención al detalle', 'Autonomía en el aprendizaje']",
#        "['Autonomía en el aprendizaje', 'Adaptabilidad al cambio', 'Comunicación escrita', 'Trabajo en equipo', 'Visión crítica', 'Proactividad']",
#        "['Aprendizaje Continuo', 'Adaptabilidad al cambio', 'Atención al detalle', 'Pensamiento analítico', 'Proactividad']",
#        "['Habilidades de negociación', 'Visión estratégica', 'Capacidad de presentación', 'Proactividad', 'Capacidad de abstracción', 'Capacidad de mentorización', 'Comunicación intercultural']",
#        "['Aprendizaje Continuo', 'Pensamiento analítico', 'Proactividad', 'Pensamiento creativo', 'Visión estratégica', 'Atención al detalle']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Capacidad de escucha', 'Proactividad', 'Atención al detalle', 'Gestión de equipo', 'Capacidad de abstracción', 'Pensamiento creativo', 'Capacidad de presentación', 'Visión crítica']",
#        "['Gestión de equipo', 'Liderazgo', 'Habilidades de negociación', 'Comunicación verbal', 'Inteligencia emocional', 'Capacidad de autogestión', 'Capacidad de dar feedback']",
#        "['Adaptabilidad al cambio', 'Trabajo en equipo', 'Proactividad', 'Capacidad de mentorización', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Gestión de equipo', 'Liderazgo']",
#        "['Adaptabilidad al cambio', 'Comunicación verbal', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Proactividad', 'Autonomía en el aprendizaje', 'Visión estratégica']",
#        "['Proactividad', 'Autonomía en el aprendizaje', 'Aprendizaje Continuo']",
#        "['Comunicación escrita', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Proactividad', 'Liderazgo', 'Capacidad de dar feedback']",
#        "['Proactividad', 'Trabajo en equipo', 'Pensamiento analítico', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Visión estratégica', 'Resistencia a la frustración']",
#        "['Proactividad', 'Trabajo en equipo', 'Capacidad de autogestión', 'Comunicación verbal', 'Capacidad de recibir feedback', 'Capacidad de dar feedback']",
#        "['Pensamiento analítico', 'Trabajo en equipo', 'Comunicación verbal', 'Atención al detalle', 'Proactividad', 'Aprendizaje Continuo', 'Capacidad de escucha']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Trabajo en equipo', 'Pensamiento creativo', 'Visión estratégica']",
#        "['Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Proactividad', 'Trabajo en equipo', 'Comunicación verbal']",
#        "['Adaptabilidad al cambio', 'Atención al detalle', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Pensamiento analítico', 'Proactividad']",
#        "['Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Pensamiento analítico', 'Trabajo en equipo', 'Atención al detalle', 'Proactividad']",
#        "['Aprendizaje Continuo', 'Capacidad de autogestión', 'Autonomía en el aprendizaje', 'Proactividad']",
#        "['Atención al detalle', 'Capacidad de autogestión', 'Pensamiento analítico', 'Trabajo en equipo', 'Comunicación escrita', 'Comunicación verbal', 'Visión crítica']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Comunicación escrita', 'Comunicación verbal', 'Pensamiento creativo', 'Tolerancia a la incertidumbre', 'Comunicación intercultural']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Comunicación verbal']",
#        "['Capacidad de autogestión', 'Proactividad', 'Trabajo en equipo', 'Comunicación verbal', 'Comunicación intercultural', 'Pensamiento analítico']",
#        "['Pensamiento analítico', 'Visión estratégica', 'Adaptabilidad al cambio', 'Proactividad', 'Gestión de equipo', 'Liderazgo']",
#        "['Pensamiento analítico', 'Proactividad', 'Trabajo en equipo', 'Inteligencia emocional', 'Aprendizaje Continuo', 'Comunicación escrita', 'Capacidad de mentorización', 'Liderazgo']",
#        "['Trabajo en equipo', 'Autonomía en el aprendizaje', 'Proactividad', 'Liderazgo', 'Comunicación verbal', 'Atención al detalle']",
#        "['Proactividad', 'Comunicación verbal', 'Comunicación intercultural', 'Capacidad de mentorización']",
#        "['Capacidad de escucha', 'Trabajo en equipo', 'Proactividad', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Capacidad de autogestión']",
#        "['Habilidades de negociación', 'Comunicación verbal', 'Atención al detalle', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Proactividad', 'Visión estratégica']",
#        "['Gestión de equipo', 'Comunicación verbal', 'Atención al detalle', 'Liderazgo', 'Capacidad de autogestión', 'Trabajo en equipo', 'Habilidades de negociación', 'Pensamiento creativo', 'Visión crítica', 'Visión estratégica', 'Capacidad de mentorización', 'Capacidad de presentación']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Comunicación verbal', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Inteligencia emocional', 'Pensamiento creativo', 'Proactividad', 'Trabajo en equipo', 'Capacidad de abstracción', 'Capacidad de escucha', 'Pensamiento analítico', 'Resistencia a la frustración', 'Visión crítica', 'Tolerancia a la incertidumbre', 'Capacidad de presentación']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Proactividad', 'Visión crítica', 'Adaptabilidad al cambio', 'Capacidad de dar feedback', 'Comunicación intercultural']",
#        "['Proactividad', 'Adaptabilidad al cambio', 'Trabajo en equipo', 'Atención al detalle', 'Aprendizaje Continuo', 'Inteligencia emocional', 'Capacidad de autogestión', 'Pensamiento analítico', 'Visión estratégica']",
#        "['Adaptabilidad al cambio', 'Comunicación verbal', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Pensamiento analítico', 'Capacidad de escucha', 'Proactividad', 'Trabajo en equipo', 'Visión crítica', 'Capacidad de autogestión', 'Tolerancia a la incertidumbre', 'Liderazgo']",
#        "['Aprendizaje Continuo', 'Pensamiento creativo', 'Trabajo en equipo', 'Comunicación escrita']",
#        "['Trabajo en equipo', 'Proactividad', 'Liderazgo', 'Capacidad de mentorización', 'Gestión de equipo', 'Aprendizaje Continuo']",
#        "['Liderazgo', 'Habilidades de negociación', 'Trabajo en equipo', 'Proactividad', 'Pensamiento analítico', 'Visión estratégica', 'Gestión de equipo']",
#        "['Pensamiento analítico', 'Trabajo en equipo', 'Autonomía en el aprendizaje', 'Comunicación verbal', 'Atención al detalle', 'Proactividad', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Gestión de equipo']",
#        "['Comunicación verbal', 'Adaptabilidad al cambio', 'Capacidad de autogestión', 'Aprendizaje Continuo', 'Atención al detalle', 'Liderazgo', 'Proactividad']",
#        "['Capacidad de autogestión', 'Visión estratégica', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Comunicación verbal']",
#        "['Adaptabilidad al cambio', 'Proactividad', 'Trabajo en equipo', 'Capacidad de mentorización', 'Resistencia a la frustración', 'Autonomía en el aprendizaje', 'Atención al detalle']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Aprendizaje Continuo', 'Capacidad de dar feedback', 'Atención al detalle', 'Tolerancia a la incertidumbre']",
#        "['Comunicación verbal', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Atención al detalle', 'Capacidad de recibir feedback', 'Inteligencia emocional']",
#        "['Autonomía en el aprendizaje', 'Comunicación verbal', 'Proactividad', 'Aprendizaje Continuo', 'Pensamiento analítico', 'Inteligencia emocional', 'Visión crítica']",
#        "['Tolerancia a la incertidumbre', 'Capacidad de autogestión', 'Liderazgo', 'Inteligencia emocional', 'Resistencia a la frustración', 'Pensamiento creativo']",
#        "['Proactividad', 'Capacidad de autogestión', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Tolerancia a la incertidumbre']",
#        "['Pensamiento analítico', 'Trabajo en equipo', 'Capacidad de autogestión', 'Adaptabilidad al cambio', 'Visión estratégica', 'Liderazgo']",
#        "['Comunicación escrita', 'Aprendizaje Continuo', 'Capacidad de escucha', 'Adaptabilidad al cambio', 'Comunicación verbal', 'Atención al detalle', 'Liderazgo', 'Pensamiento creativo', 'Pensamiento analítico']",
#        "['Adaptabilidad al cambio', 'Pensamiento analítico', 'Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de recibir feedback', 'Proactividad', 'Capacidad de autogestión', 'Capacidad de dar feedback']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Atención al detalle', 'Proactividad', 'Tolerancia a la incertidumbre', 'Comunicación intercultural']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Comunicación verbal', 'Trabajo en equipo', 'Proactividad', 'Visión estratégica', 'Capacidad de autogestión', 'Capacidad de presentación', 'Visión crítica']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Trabajo en equipo', 'Proactividad', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Pensamiento analítico', 'Visión crítica', 'Capacidad de dar feedback']",
#        "['Comunicación verbal', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Comunicación escrita', 'Liderazgo', 'Proactividad']",
#        "['Atención al detalle', 'Pensamiento creativo', 'Pensamiento analítico', 'Inteligencia emocional', 'Trabajo en equipo']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Proactividad', 'Pensamiento analítico', 'Trabajo en equipo', 'Capacidad de autogestión', 'Capacidad de mentorización', 'Tolerancia a la incertidumbre', 'Gestión de equipo', 'Liderazgo', 'Visión estratégica']",
#        "['Adaptabilidad al cambio', 'Proactividad', 'Atención al detalle', 'Comunicación verbal', 'Capacidad de autogestión', 'Capacidad de abstracción', 'Inteligencia emocional', 'Capacidad de dar feedback', 'Capacidad de recibir feedback']",
#        "['Pensamiento analítico', 'Pensamiento creativo', 'Proactividad', 'Capacidad de presentación', 'Visión estratégica', 'Trabajo en equipo']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de escucha', 'Proactividad', 'Trabajo en equipo', 'Autonomía en el aprendizaje', 'Capacidad de autogestión']",
#        "['Aprendizaje Continuo', 'Proactividad', 'Trabajo en equipo']",
#        "['Liderazgo', 'Gestión de equipo', 'Capacidad de autogestión', 'Capacidad de mentorización', 'Pensamiento analítico', 'Comunicación intercultural']",
#        "['Capacidad de autogestión', 'Proactividad', 'Trabajo en equipo', 'Gestión de equipo', 'Tolerancia a la incertidumbre', 'Aprendizaje Continuo', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Visión estratégica']",
#        "['Proactividad', 'Aprendizaje Continuo', 'Trabajo en equipo']",
#        "['Liderazgo', 'Habilidades de negociación', 'Capacidad de autogestión', 'Proactividad', 'Visión estratégica', 'Atención al detalle', 'Gestión de equipo']",
#        "['Capacidad de autogestión', 'Aprendizaje Continuo', 'Comunicación verbal', 'Adaptabilidad al cambio', 'Proactividad', 'Liderazgo']",
#        "['Capacidad de autogestión', 'Tolerancia a la incertidumbre', 'Trabajo en equipo', 'Comunicación verbal', 'Proactividad', 'Pensamiento analítico', 'Atención al detalle', 'Visión estratégica']",
#        "['Comunicación escrita', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Atención al detalle', 'Capacidad de dar feedback', 'Proactividad', 'Resistencia a la frustración']",
#        "['Trabajo en equipo', 'Proactividad', 'Capacidad de autogestión', 'Pensamiento analítico', 'Aprendizaje Continuo', 'Adaptabilidad al cambio', 'Atención al detalle']",
#        "['Inteligencia emocional', 'Proactividad', 'Capacidad de escucha', 'Comunicación verbal', 'Autonomía en el aprendizaje', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Capacidad de recibir feedback', 'Capacidad de mentorización']",
#        "['Aprendizaje Continuo', 'Proactividad', 'Trabajo en equipo', 'Visión crítica', 'Capacidad de autogestión', 'Autonomía en el aprendizaje', 'Adaptabilidad al cambio', 'Liderazgo']",
#        "['Trabajo en equipo', 'Proactividad', 'Aprendizaje Continuo', 'Adaptabilidad al cambio', 'Atención al detalle', 'Capacidad de escucha', 'Comunicación verbal']",
#        "['Adaptabilidad al cambio', 'Comunicación verbal', 'Aprendizaje Continuo', 'Pensamiento analítico', 'Proactividad', 'Trabajo en equipo', 'Visión crítica', 'Capacidad de autogestión', 'Tolerancia a la incertidumbre', 'Liderazgo']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Proactividad', 'Comunicación verbal', 'Pensamiento creativo', 'Tolerancia a la incertidumbre']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Proactividad', 'Pensamiento analítico', 'Adaptabilidad al cambio', 'Capacidad de dar feedback', 'Comunicación intercultural']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Proactividad', 'Trabajo en equipo', 'Capacidad de autogestión']",
#        "['Trabajo en equipo', 'Proactividad', 'Aprendizaje Continuo']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Comunicación verbal', 'Capacidad de autogestión', 'Proactividad']",
#        "['Gestión de equipo', 'Proactividad', 'Trabajo en equipo', 'Liderazgo', 'Capacidad de mentorización', 'Aprendizaje Continuo', 'Pensamiento analítico']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Habilidades de negociación', 'Gestión de equipo', 'Capacidad de dar feedback', 'Atención al detalle', 'Capacidad de presentación', 'Tolerancia a la incertidumbre']",
#        "['Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Trabajo en equipo', 'Proactividad', 'Pensamiento analítico']",
#        "['Adaptabilidad al cambio', 'Capacidad de dar feedback', 'Proactividad', 'Atención al detalle', 'Trabajo en equipo']",
#        "['Atención al detalle', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Pensamiento analítico', 'Proactividad']",
#        "['Trabajo en equipo', 'Proactividad', 'Capacidad de mentorización', 'Comunicación verbal', 'Liderazgo']",
#        "['Adaptabilidad al cambio', 'Capacidad de autogestión', 'Proactividad', 'Trabajo en equipo', 'Atención al detalle', 'Resistencia a la frustración', 'Capacidad de presentación']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Pensamiento analítico', 'Comunicación verbal', 'Aprendizaje Continuo', 'Visión estratégica', 'Proactividad']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de autogestión', 'Trabajo en equipo', 'Comunicación verbal', 'Pensamiento analítico', 'Capacidad de mentorización']",
#        "['Adaptabilidad al cambio', 'Proactividad', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Visión estratégica']",
#        "['Adaptabilidad al cambio', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Liderazgo', 'Proactividad', 'Pensamiento analítico', 'Pensamiento creativo']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Adaptabilidad al cambio', 'Comunicación escrita', 'Capacidad de autogestión', 'Autonomía en el aprendizaje', 'Proactividad']",
#        "['Proactividad', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Trabajo en equipo', 'Visión crítica', 'Capacidad de autogestión']",
#        "['Pensamiento creativo', 'Trabajo en equipo', 'Visión estratégica', 'Comunicación intercultural', 'Visión crítica']",
#        "['Capacidad de autogestión', 'Pensamiento analítico', 'Autonomía en el aprendizaje', 'Trabajo en equipo', 'Liderazgo', 'Visión estratégica', 'Comunicación intercultural']",
#        "['Atención al detalle', 'Capacidad de dar feedback', 'Pensamiento analítico', 'Comunicación verbal', 'Comunicación escrita', 'Capacidad de autogestión']",
#        "['Trabajo en equipo', 'Liderazgo', 'Comunicación verbal', 'Comunicación escrita', 'Capacidad de dar feedback', 'Capacidad de mentorización']",
#        "['Tolerancia a la incertidumbre', 'Adaptabilidad al cambio', 'Comunicación verbal', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Capacidad de presentación', 'Gestión de equipo', 'Capacidad de mentorización']",
#        "['Pensamiento analítico', 'Capacidad de autogestión', 'Trabajo en equipo', 'Autonomía en el aprendizaje', 'Proactividad', 'Aprendizaje Continuo', 'Atención al detalle']",
#        "['Gestión de equipo', 'Liderazgo', 'Capacidad de mentorización', 'Trabajo en equipo', 'Atención al detalle', 'Proactividad', 'Pensamiento creativo', 'Visión estratégica']",
#        "['Liderazgo', 'Comunicación escrita', 'Comunicación verbal', 'Atención al detalle', 'Proactividad', 'Habilidades de negociación', 'Capacidad de presentación']",
#        "['Atención al detalle', 'Capacidad de autogestión', 'Gestión de equipo', 'Adaptabilidad al cambio', 'Capacidad de recibir feedback', 'Proactividad']",
#        "['Trabajo en equipo', 'Proactividad', 'Autonomía en el aprendizaje', 'Aprendizaje Continuo', 'Adaptabilidad al cambio']",
#        "['Trabajo en equipo', 'Capacidad de autogestión', 'Proactividad', 'Aprendizaje Continuo', 'Atención al detalle', 'Comunicación verbal', 'Capacidad de mentorización']",
#        "['Comunicación verbal', 'Comunicación escrita', 'Liderazgo', 'Habilidades de negociación', 'Pensamiento analítico', 'Visión estratégica', 'Trabajo en equipo', 'Inteligencia emocional', 'Capacidad de autogestión']",
#        "['Trabajo en equipo', 'Proactividad', 'Capacidad de autogestión', 'Pensamiento analítico', 'Adaptabilidad al cambio', 'Atención al detalle']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Capacidad de recibir feedback', 'Capacidad de dar feedback', 'Atención al detalle', 'Capacidad de autogestión', 'Proactividad', 'Pensamiento analítico']",
#        "['Visión crítica', 'Proactividad', 'Trabajo en equipo', 'Capacidad de abstracción', 'Capacidad de mentorización']",
#        "['Aprendizaje Continuo', 'Capacidad de autogestión', 'Trabajo en equipo', 'Comunicación verbal', 'Atención al detalle']",
#        "['Adaptabilidad al cambio', 'Liderazgo', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Trabajo en equipo', 'Comunicación escrita', 'Aprendizaje Continuo', 'Capacidad de escucha', 'Pensamiento creativo', 'Gestión de equipo', 'Capacidad de mentorización', 'Resistencia a la frustración']",
#        "['Comunicación verbal', 'Capacidad de autogestión', 'Capacidad de recibir feedback', 'Trabajo en equipo', 'Gestión de equipo', 'Autonomía en el aprendizaje', 'Tolerancia a la incertidumbre', 'Visión crítica', 'Proactividad']",
#        "['Aprendizaje Continuo', 'Proactividad', 'Comunicación escrita', 'Autonomía en el aprendizaje']",
#        "['Proactividad', 'Capacidad de dar feedback', 'Trabajo en equipo', 'Visión crítica', 'Visión estratégica']",
#        "['Atención al detalle', 'Trabajo en equipo', 'Proactividad', 'Aprendizaje Continuo', 'Pensamiento creativo', 'Visión crítica']",
#        "['Liderazgo', 'Pensamiento analítico', 'Capacidad de autogestión', 'Gestión de equipo', 'Trabajo en equipo', 'Inteligencia emocional', 'Capacidad de mentorización']",
#        "['Adaptabilidad al cambio', 'Proactividad', 'Trabajo en equipo', 'Atención al detalle', 'Liderazgo', 'Aprendizaje Continuo', 'Comunicación verbal']",
#        "['Liderazgo', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Capacidad de presentación', 'Comunicación escrita', 'Proactividad', 'Atención al detalle', 'Visión crítica', 'Tolerancia a la incertidumbre', 'Adaptabilidad al cambio']",
#        "['Comunicación verbal', 'Proactividad', 'Capacidad de dar feedback', 'Trabajo en equipo', 'Capacidad de autogestión', 'Capacidad de recibir feedback']",
#        "['Pensamiento analítico', 'Aprendizaje Continuo', 'Proactividad', 'Trabajo en equipo', 'Visión estratégica', 'Liderazgo', 'Capacidad de dar feedback', 'Capacidad de autogestión', 'Visión crítica', 'Capacidad de mentorización']",
#        "['Trabajo en equipo', 'Pensamiento analítico', 'Proactividad', 'Comunicación verbal', 'Liderazgo', 'Gestión de equipo', 'Visión estratégica']",
#        "['Aprendizaje Continuo', 'Proactividad', 'Capacidad de autogestión', 'Atención al detalle', 'Trabajo en equipo', 'Capacidad de escucha', 'Capacidad de dar feedback']",
#        "['Adaptabilidad al cambio', 'Pensamiento analítico', 'Proactividad', 'Aprendizaje Continuo', 'Capacidad de mentorización', 'Trabajo en equipo', 'Liderazgo', 'Resistencia a la frustración']",
#        "['Aprendizaje Continuo', 'Comunicación escrita', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Capacidad de mentorización', 'Liderazgo']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Liderazgo', 'Inteligencia emocional', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Capacidad de escucha', 'Proactividad', 'Habilidades de negociación', 'Gestión de equipo', 'Capacidad de abstracción', 'Pensamiento creativo', 'Capacidad de mentorización', 'Resistencia a la frustración', 'Capacidad de presentación', 'Tolerancia a la incertidumbre', 'Visión crítica', 'Atención al detalle']",
#        "['Trabajo en equipo', 'Pensamiento analítico', 'Atención al detalle', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Comunicación verbal', 'Proactividad', 'Capacidad de mentorización']",
#        "['Capacidad de recibir feedback', 'Capacidad de escucha', 'Proactividad', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Resistencia a la frustración', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Capacidad de dar feedback']",
#        "['Comunicación verbal', 'Atención al detalle', 'Liderazgo', 'Proactividad', 'Adaptabilidad al cambio', 'Comunicación escrita', 'Capacidad de autogestión', 'Visión crítica']",
#        "['Proactividad', 'Adaptabilidad al cambio', 'Atención al detalle', 'Trabajo en equipo', 'Capacidad de escucha', 'Aprendizaje Continuo']",
#        "['Comunicación verbal', 'Habilidades de negociación', 'Trabajo en equipo', 'Visión estratégica', 'Atención al detalle', 'Proactividad', 'Adaptabilidad al cambio', 'Resistencia a la frustración']",
#        "['Comunicación verbal', 'Comunicación escrita', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Adaptabilidad al cambio']",
#        "['Capacidad de autogestión', 'Pensamiento analítico', 'Trabajo en equipo', 'Proactividad', 'Capacidad de recibir feedback', 'Aprendizaje Continuo']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Gestión de equipo', 'Proactividad', 'Capacidad de mentorización', 'Comunicación verbal', 'Atención al detalle']",
#        "['Atención al detalle', 'Trabajo en equipo', 'Visión estratégica', 'Capacidad de recibir feedback', 'Capacidad de presentación', 'Capacidad de autogestión', 'Pensamiento analítico', 'Adaptabilidad al cambio', 'Tolerancia a la incertidumbre']",
#        "['Capacidad de autogestión', 'Proactividad', 'Trabajo en equipo']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Adaptabilidad al cambio', 'Inteligencia emocional', 'Comunicación escrita', 'Tolerancia a la incertidumbre']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo', 'Proactividad', 'Comunicación escrita', 'Autonomía en el aprendizaje', 'Capacidad de recibir feedback', 'Pensamiento analítico']",
#        "['Trabajo en equipo', 'Comunicación verbal', 'Proactividad', 'Aprendizaje Continuo', 'Capacidad de escucha', 'Capacidad de recibir feedback']",
#        "['Adaptabilidad al cambio', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de autogestión', 'Pensamiento analítico', 'Capacidad de mentorización']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Proactividad', 'Trabajo en equipo']",
#        "['Adaptabilidad al cambio', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Tolerancia a la incertidumbre']",
#        "['Adaptabilidad al cambio', 'Capacidad de autogestión', 'Pensamiento creativo', 'Pensamiento analítico', 'Visión estratégica', 'Trabajo en equipo']",
#        "['Trabajo en equipo', 'Atención al detalle', 'Capacidad de autogestión', 'Proactividad', 'Autonomía en el aprendizaje', 'Pensamiento creativo']",
#        "['Inteligencia emocional', 'Capacidad de escucha', 'Trabajo en equipo', 'Pensamiento analítico', 'Pensamiento creativo', 'Atención al detalle', 'Proactividad']",
#        "['Capacidad de dar feedback', 'Trabajo en equipo', 'Liderazgo', 'Adaptabilidad al cambio', 'Comunicación intercultural']",
#        "['Trabajo en equipo', 'Capacidad de autogestión', 'Autonomía en el aprendizaje', 'Pensamiento analítico', 'Proactividad']",
#        "['Habilidades de negociación', 'Capacidad de escucha', 'Comunicación escrita', 'Comunicación verbal', 'Gestión de equipo', 'Resistencia a la frustración']",
#        "['Adaptabilidad al cambio', 'Capacidad de dar feedback', 'Proactividad', 'Capacidad de mentorización', 'Atención al detalle', 'Trabajo en equipo']",
#        "['Proactividad', 'Capacidad de recibir feedback', 'Capacidad de dar feedback', 'Capacidad de autogestión', 'Visión estratégica', 'Atención al detalle', 'Comunicación intercultural']",
#        "['Aprendizaje Continuo', 'Capacidad de presentación', 'Pensamiento creativo', 'Pensamiento analítico', 'Visión estratégica', 'Trabajo en equipo']",
#        "['Trabajo en equipo', 'Atención al detalle', 'Comunicación escrita', 'Comunicación verbal', 'Aprendizaje Continuo', 'Liderazgo']",
#        "['Adaptabilidad al cambio', 'Comunicación escrita', 'Capacidad de autogestión', 'Proactividad', 'Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de dar feedback']",
#        "['Pensamiento analítico', 'Capacidad de autogestión', 'Trabajo en equipo', 'Proactividad', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Adaptabilidad al cambio']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Proactividad']",
#        "['Trabajo en equipo', 'Atención al detalle', 'Aprendizaje Continuo']",
#        "['Aprendizaje Continuo', 'Comunicación escrita', 'Comunicación verbal', 'Capacidad de autogestión']",
#        "['Gestión de equipo', 'Liderazgo', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Proactividad', 'Trabajo en equipo', 'Visión estratégica', 'Aprendizaje Continuo', 'Resistencia a la frustración']",
#        "['Adaptabilidad al cambio', 'Capacidad de autogestión', 'Trabajo en equipo', 'Liderazgo']",
#        "['Habilidades de negociación', 'Capacidad de dar feedback', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Pensamiento analítico', 'Resistencia a la frustración', 'Autonomía en el aprendizaje']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Aprendizaje Continuo', 'Proactividad', 'Atención al detalle']",
#        "['Atención al detalle', 'Aprendizaje Continuo', 'Proactividad', 'Comunicación intercultural', 'Pensamiento analítico', 'Comunicación verbal']",
#        "['Atención al detalle', 'Adaptabilidad al cambio', 'Capacidad de autogestión', 'Proactividad', 'Autonomía en el aprendizaje', 'Pensamiento analítico', 'Capacidad de recibir feedback']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de autogestión', 'Trabajo en equipo', 'Gestión de equipo', 'Capacidad de mentorización', 'Comunicación intercultural']",
#        "['Proactividad', 'Capacidad de autogestión', 'Trabajo en equipo', 'Pensamiento analítico', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Adaptabilidad al cambio']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo', 'Pensamiento analítico', 'Proactividad', 'Atención al detalle', 'Comunicación escrita']",
#        "['Atención al detalle', 'Trabajo en equipo', 'Comunicación verbal', 'Pensamiento creativo', 'Comunicación escrita', 'Capacidad de autogestión', 'Adaptabilidad al cambio']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Autonomía en el aprendizaje', 'Capacidad de recibir feedback']",
#        "['Comunicación verbal', 'Comunicación intercultural', 'Comunicación escrita', 'Inteligencia emocional', 'Liderazgo', 'Proactividad', 'Trabajo en equipo']",
#        "['Habilidades de negociación', 'Capacidad de presentación', 'Comunicación verbal', 'Comunicación escrita', 'Atención al detalle', 'Pensamiento analítico', 'Capacidad de dar feedback']",
#        "['Atención al detalle', 'Capacidad de autogestión', 'Proactividad', 'Trabajo en equipo', 'Capacidad de dar feedback', 'Capacidad de recibir feedback']",
#        "['Atención al detalle', 'Capacidad de autogestión', 'Comunicación verbal']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Liderazgo', 'Capacidad de mentorización', 'Proactividad', 'Comunicación verbal', 'Resistencia a la frustración']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Trabajo en equipo', 'Capacidad de abstracción', 'Capacidad de autogestión']",
#        "['Habilidades de negociación', 'Gestión de equipo', 'Proactividad', 'Pensamiento creativo', 'Inteligencia emocional', 'Pensamiento analítico']",
#        "['Atención al detalle', 'Trabajo en equipo', 'Comunicación verbal', 'Comunicación escrita', 'Visión estratégica', 'Capacidad de autogestión', 'Proactividad']",
#        "['Liderazgo', 'Autonomía en el aprendizaje', 'Proactividad', 'Trabajo en equipo', 'Pensamiento analítico', 'Atención al detalle']",
#        "['Capacidad de recibir feedback', 'Atención al detalle', 'Comunicación escrita', 'Pensamiento analítico']",
#        "['Comunicación escrita', 'Comunicación verbal', 'Gestión de equipo', 'Adaptabilidad al cambio', 'Liderazgo', 'Pensamiento analítico', 'Inteligencia emocional', 'Pensamiento creativo']",
#        "['Proactividad', 'Aprendizaje Continuo', 'Capacidad de recibir feedback', 'Trabajo en equipo']",
#        "['Trabajo en equipo', 'Proactividad', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Capacidad de recibir feedback']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Atención al detalle', 'Adaptabilidad al cambio', 'Capacidad de dar feedback', 'Comunicación intercultural', 'Proactividad', 'Aprendizaje Continuo']",
#        "['Liderazgo', 'Trabajo en equipo', 'Capacidad de dar feedback', 'Capacidad de autogestión']",
#        "['Gestión de equipo', 'Liderazgo', 'Visión estratégica', 'Comunicación verbal', 'Capacidad de mentorización', 'Atención al detalle', 'Capacidad de presentación']",
#        "['Pensamiento analítico', 'Pensamiento creativo', 'Proactividad', 'Capacidad de autogestión', 'Adaptabilidad al cambio']",
#        "['Comunicación verbal', 'Comunicación escrita', 'Pensamiento analítico']",
#        "['Pensamiento creativo', 'Autonomía en el aprendizaje', 'Trabajo en equipo', 'Comunicación intercultural', 'Visión estratégica']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Proactividad', 'Pensamiento creativo', 'Comunicación verbal', 'Capacidad de dar feedback', 'Trabajo en equipo']",
#        "['Aprendizaje Continuo', 'Capacidad de recibir feedback', 'Capacidad de dar feedback', 'Proactividad', 'Pensamiento analítico', 'Autonomía en el aprendizaje']",
#        "['Proactividad', 'Adaptabilidad al cambio', 'Comunicación verbal', 'Aprendizaje Continuo', 'Gestión de equipo', 'Liderazgo', 'Habilidades de negociación']",
#        "['Trabajo en equipo', 'Proactividad', 'Aprendizaje Continuo', 'Atención al detalle', 'Pensamiento creativo', 'Capacidad de dar feedback', 'Liderazgo', 'Visión estratégica']",
#        "['Aprendizaje Continuo', 'Comunicación escrita', 'Comunicación verbal', 'Resistencia a la frustración', 'Proactividad', 'Trabajo en equipo']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Liderazgo', 'Habilidades de negociación', 'Pensamiento analítico', 'Visión estratégica', 'Capacidad de abstracción', 'Tolerancia a la incertidumbre', 'Visión crítica', 'Capacidad de mentorización', 'Pensamiento creativo']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Proactividad', 'Atención al detalle', 'Comunicación escrita']",
#        "['Atención al detalle', 'Trabajo en equipo', 'Proactividad', 'Autonomía en el aprendizaje', 'Tolerancia a la incertidumbre']",
#        "['Comunicación verbal', 'Proactividad', 'Capacidad de autogestión', 'Trabajo en equipo', 'Resistencia a la frustración', 'Comunicación escrita', 'Capacidad de dar feedback', 'Habilidades de negociación', 'Comunicación intercultural']",
#        "['Trabajo en equipo', 'Aprendizaje Continuo', 'Atención al detalle', 'Proactividad', 'Autonomía en el aprendizaje', 'Adaptabilidad al cambio', 'Capacidad de autogestión']",
#        "['Aprendizaje Continuo', 'Capacidad de autogestión', 'Trabajo en equipo', 'Adaptabilidad al cambio', 'Comunicación verbal', 'Capacidad de dar feedback', 'Proactividad']",
#        "['Aprendizaje Continuo', 'Proactividad', 'Trabajo en equipo', 'Adaptabilidad al cambio', 'Comunicación verbal', 'Capacidad de autogestión', 'Inteligencia emocional']",
#        "['Trabajo en equipo', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Pensamiento analítico', 'Proactividad', 'Comunicación verbal', 'Comunicación escrita']",
#        "['Adaptabilidad al cambio', 'Comunicación escrita', 'Comunicación verbal', 'Trabajo en equipo', 'Atención al detalle', 'Capacidad de autogestión', 'Pensamiento creativo']",
#        "['Atención al detalle', 'Capacidad de recibir feedback', 'Autonomía en el aprendizaje', 'Capacidad de dar feedback', 'Aprendizaje Continuo', 'Inteligencia emocional']",
#        "['Aprendizaje Continuo', 'Capacidad de autogestión', 'Trabajo en equipo', 'Pensamiento analítico', 'Comunicación verbal', 'Proactividad', 'Habilidades de negociación', 'Comunicación escrita', 'Visión crítica']",
#        "['Liderazgo', 'Gestión de equipo', 'Comunicación verbal', 'Capacidad de dar feedback']",
#        "['Adaptabilidad al cambio', 'Atención al detalle', 'Capacidad de autogestión', 'Aprendizaje Continuo', 'Comunicación escrita', 'Comunicación verbal']",
#        "['Atención al detalle', 'Comunicación verbal', 'Comunicación escrita', 'Trabajo en equipo', 'Capacidad de abstracción', 'Capacidad de mentorización', 'Gestión de equipo', 'Liderazgo']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Autonomía en el aprendizaje']",
#        "['Trabajo en equipo', 'Pensamiento analítico', 'Aprendizaje Continuo', 'Proactividad', 'Visión crítica', 'Autonomía en el aprendizaje', 'Capacidad de recibir feedback', 'Capacidad de abstracción']",
#        "['Aprendizaje Continuo', 'Capacidad de abstracción', 'Atención al detalle', 'Pensamiento analítico', 'Inteligencia emocional', 'Comunicación verbal', 'Visión estratégica']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Comunicación verbal', 'Capacidad de mentorización']",
#        "['Capacidad de autogestión', 'Capacidad de abstracción', 'Trabajo en equipo', 'Liderazgo', 'Comunicación escrita', 'Pensamiento analítico', 'Comunicación verbal']",
#        "['Liderazgo', 'Gestión de equipo', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Visión crítica', 'Visión estratégica']",
#        "['Capacidad de autogestión', 'Proactividad', 'Visión crítica', 'Trabajo en equipo', 'Autonomía en el aprendizaje']",
#        "['Adaptabilidad al cambio', 'Liderazgo', 'Habilidades de negociación', 'Capacidad de mentorización', 'Proactividad', 'Capacidad de presentación', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Visión estratégica']",
#        "['Trabajo en equipo', 'Comunicación escrita', 'Capacidad de dar feedback', 'Inteligencia emocional', 'Capacidad de recibir feedback', 'Aprendizaje Continuo', 'Atención al detalle', 'Autonomía en el aprendizaje']",
#        "['Atención al detalle', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Visión crítica']",
# ...
#        "['Proactividad', 'Pensamiento analítico', 'Trabajo en equipo', 'Adaptabilidad al cambio', 'Capacidad de autogestión', 'Pensamiento creativo']",
#        "['Atención al detalle', 'Capacidad de recibir feedback', 'Capacidad de presentación', 'Trabajo en equipo', 'Visión estratégica', 'Pensamiento analítico', 'Capacidad de autogestión', 'Adaptabilidad al cambio', 'Tolerancia a la incertidumbre']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Tolerancia a la incertidumbre', 'Proactividad']",
#        "['Adaptabilidad al cambio', 'Trabajo en equipo', 'Comunicación verbal', 'Capacidad de escucha', 'Habilidades de negociación', 'Pensamiento analítico', 'Proactividad']",
#        "['Atención al detalle', 'Autonomía en el aprendizaje', 'Trabajo en equipo', 'Pensamiento analítico', 'Proactividad', 'Capacidad de recibir feedback']",
#        "['Comunicación verbal', 'Gestión de equipo', 'Liderazgo', 'Capacidad de dar feedback', 'Proactividad', 'Capacidad de presentación', 'Visión estratégica', 'Inteligencia emocional', 'Tolerancia a la incertidumbre', 'Habilidades de negociación', 'Pensamiento creativo', 'Capacidad de mentorización']",
#        "['Comunicación escrita', 'Comunicación verbal', 'Pensamiento creativo', 'Trabajo en equipo', 'Pensamiento analítico', 'Proactividad', 'Visión estratégica']",
#        "['Habilidades de negociación', 'Capacidad de autogestión', 'Proactividad', 'Capacidad de presentación', 'Visión estratégica']",
#        "['Comunicación escrita', 'Trabajo en equipo', 'Proactividad', 'Aprendizaje Continuo', 'Resistencia a la frustración', 'Comunicación verbal']",
#        "['Trabajo en equipo', 'Adaptabilidad al cambio', 'Capacidad de dar feedback', 'Liderazgo', 'Inteligencia emocional', 'Comunicación escrita', 'Resistencia a la frustración']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo', 'Liderazgo', 'Capacidad de abstracción', 'Adaptabilidad al cambio', 'Capacidad de mentorización', 'Pensamiento creativo', 'Proactividad']",
#        "['Capacidad de dar feedback', 'Capacidad de autogestión', 'Pensamiento creativo', 'Trabajo en equipo', 'Adaptabilidad al cambio', 'Inteligencia emocional', 'Tolerancia a la incertidumbre', 'Visión estratégica', 'Visión crítica']",
#        "['Capacidad de autogestión', 'Capacidad de escucha', 'Trabajo en equipo', 'Aprendizaje Continuo']",
#        "['Proactividad', 'Capacidad de autogestión', 'Trabajo en equipo', 'Atención al detalle', 'Liderazgo', 'Aprendizaje Continuo', 'Gestión de equipo', 'Tolerancia a la incertidumbre']",
#        "['Atención al detalle', 'Trabajo en equipo', 'Visión estratégica', 'Capacidad de autogestión', 'Proactividad']",
#        "['Adaptabilidad al cambio', 'Capacidad de autogestión', 'Trabajo en equipo', 'Capacidad de presentación', 'Visión crítica', 'Comunicación escrita']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Autonomía en el aprendizaje', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Proactividad', 'Tolerancia a la incertidumbre']",
#        "['Capacidad de escucha', 'Proactividad', 'Trabajo en equipo', 'Adaptabilidad al cambio', 'Comunicación verbal', 'Aprendizaje Continuo']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Proactividad', 'Autonomía en el aprendizaje', 'Visión crítica', 'Adaptabilidad al cambio']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de autogestión', 'Trabajo en equipo', 'Adaptabilidad al cambio', 'Comunicación verbal']",
#        "['Trabajo en equipo', 'Comunicación verbal', 'Pensamiento analítico', 'Proactividad', 'Adaptabilidad al cambio', 'Atención al detalle']",
#        "['Atención al detalle', 'Autonomía en el aprendizaje', 'Proactividad', 'Adaptabilidad al cambio', 'Pensamiento creativo']",
#        "['Liderazgo', 'Capacidad de dar feedback', 'Gestión de equipo', 'Capacidad de autogestión', 'Adaptabilidad al cambio']",
#        "['Trabajo en equipo', 'Capacidad de autogestión', 'Proactividad', 'Pensamiento analítico', 'Aprendizaje Continuo', 'Atención al detalle', 'Adaptabilidad al cambio', 'Autonomía en el aprendizaje']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Trabajo en equipo', 'Comunicación escrita', 'Proactividad']",
#        "['Aprendizaje Continuo', 'Proactividad', 'Trabajo en equipo', 'Comunicación verbal', 'Liderazgo', 'Capacidad de mentorización', 'Comunicación escrita']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Atención al detalle', 'Proactividad', 'Adaptabilidad al cambio', 'Aprendizaje Continuo']",
#        "['Pensamiento analítico', 'Aprendizaje Continuo', 'Adaptabilidad al cambio', 'Capacidad de mentorización', 'Atención al detalle', 'Proactividad', 'Comunicación escrita']",
#        "['Trabajo en equipo', 'Capacidad de abstracción', 'Pensamiento analítico', 'Visión crítica', 'Aprendizaje Continuo', 'Capacidad de mentorización', 'Capacidad de autogestión', 'Liderazgo']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Atención al detalle', 'Proactividad', 'Trabajo en equipo', 'Capacidad de escucha']",
#        "['Adaptabilidad al cambio', 'Comunicación verbal', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Capacidad de autogestión']",
#        "['Aprendizaje Continuo', 'Capacidad de autogestión', 'Trabajo en equipo', 'Adaptabilidad al cambio', 'Pensamiento creativo', 'Atención al detalle']",
#        "['Proactividad', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Trabajo en equipo', 'Comunicación verbal', 'Liderazgo']",
#        "['Comunicación verbal', 'Comunicación escrita', 'Capacidad de autogestión', 'Capacidad de mentorización', 'Visión crítica']",
#        "['Comunicación escrita', 'Comunicación verbal', 'Aprendizaje Continuo', 'Proactividad', 'Trabajo en equipo', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Tolerancia a la incertidumbre', 'Visión crítica']",
#        "['Atención al detalle', 'Capacidad de autogestión', 'Liderazgo', 'Proactividad', 'Comunicación escrita', 'Capacidad de mentorización', 'Visión estratégica']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Visión estratégica', 'Atención al detalle', 'Proactividad', 'Aprendizaje Continuo']",
#        "['Adaptabilidad al cambio', 'Atención al detalle', 'Capacidad de abstracción', 'Aprendizaje Continuo', 'Capacidad de dar feedback', 'Comunicación escrita']",
#        "['Atención al detalle', 'Capacidad de autogestión', 'Comunicación verbal', 'Proactividad', 'Trabajo en equipo', 'Capacidad de escucha', 'Autonomía en el aprendizaje', 'Aprendizaje Continuo']",
#        "['Autonomía en el aprendizaje', 'Trabajo en equipo', 'Proactividad', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Comunicación verbal', 'Adaptabilidad al cambio', 'Comunicación escrita']",
#        "['Pensamiento analítico', 'Liderazgo', 'Visión estratégica', 'Gestión de equipo', 'Atención al detalle', 'Adaptabilidad al cambio', 'Aprendizaje Continuo']",
#        "['Pensamiento creativo', 'Pensamiento analítico', 'Autonomía en el aprendizaje', 'Comunicación intercultural', 'Trabajo en equipo', 'Adaptabilidad al cambio']",
#        "['Aprendizaje Continuo', 'Capacidad de autogestión', 'Trabajo en equipo', 'Gestión de equipo', 'Liderazgo', 'Proactividad', 'Visión estratégica']",
#        "['Atención al detalle', 'Inteligencia emocional', 'Pensamiento analítico', 'Trabajo en equipo', 'Autonomía en el aprendizaje', 'Capacidad de dar feedback', 'Aprendizaje Continuo']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo', 'Proactividad', 'Atención al detalle', 'Comunicación escrita']",
#        "['Trabajo en equipo', 'Proactividad', 'Pensamiento analítico', 'Visión crítica', 'Aprendizaje Continuo', 'Pensamiento creativo']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de dar feedback', 'Capacidad de presentación', 'Tolerancia a la incertidumbre', 'Visión estratégica']",
#        "['Adaptabilidad al cambio', 'Pensamiento analítico', 'Visión crítica', 'Pensamiento creativo', 'Capacidad de autogestión', 'Gestión de equipo', 'Capacidad de mentorización', 'Visión estratégica']",
#        "['Atención al detalle', 'Gestión de equipo', 'Pensamiento creativo', 'Trabajo en equipo', 'Adaptabilidad al cambio']",
#        "['Habilidades de negociación', 'Visión estratégica', 'Adaptabilidad al cambio', 'Gestión de equipo']",
#        "['Comunicación verbal', 'Capacidad de autogestión', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Proactividad', 'Comunicación intercultural']",
#        "['Aprendizaje Continuo', 'Comunicación verbal', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Pensamiento analítico']",
#        "['Atención al detalle', 'Comunicación escrita', 'Comunicación verbal', 'Liderazgo', 'Trabajo en equipo', 'Aprendizaje Continuo', 'Capacidad de autogestión']",
#        "['Trabajo en equipo', 'Proactividad', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Pensamiento creativo']",
#        "['Trabajo en equipo', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Pensamiento analítico', 'Proactividad']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Capacidad de autogestión', 'Pensamiento creativo', 'Pensamiento analítico', 'Inteligencia emocional']",
#        "['Capacidad de autogestión', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Pensamiento creativo', 'Pensamiento analítico', 'Proactividad', 'Comunicación verbal']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Visión crítica', 'Comunicación verbal', 'Pensamiento analítico', 'Resistencia a la frustración', 'Adaptabilidad al cambio']",
#        "['Aprendizaje Continuo', 'Comunicación escrita', 'Liderazgo', 'Adaptabilidad al cambio', 'Pensamiento analítico', 'Visión estratégica', 'Pensamiento creativo']",
#        "['Aprendizaje Continuo', 'Capacidad de recibir feedback', 'Trabajo en equipo', 'Pensamiento analítico', 'Comunicación verbal', 'Capacidad de dar feedback', 'Capacidad de presentación', 'Proactividad']",
#        "['Comunicación escrita', 'Aprendizaje Continuo', 'Comunicación verbal', 'Capacidad de autogestión', 'Capacidad de dar feedback', 'Capacidad de recibir feedback', 'Autonomía en el aprendizaje', 'Pensamiento analítico', 'Capacidad de escucha', 'Visión crítica', 'Proactividad', 'Comunicación intercultural']",
#        "['Trabajo en equipo', 'Pensamiento analítico', 'Visión estratégica', 'Atención al detalle', 'Capacidad de dar feedback', 'Liderazgo', 'Adaptabilidad al cambio', 'Resistencia a la frustración', 'Visión crítica']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de autogestión', 'Trabajo en equipo', 'Capacidad de presentación', 'Comunicación escrita', 'Proactividad']",
#        "['Capacidad de escucha', 'Trabajo en equipo', 'Proactividad', 'Pensamiento analítico', 'Capacidad de autogestión', 'Capacidad de presentación']",
#        "['Adaptabilidad al cambio', 'Atención al detalle', 'Capacidad de autogestión', 'Autonomía en el aprendizaje', 'Capacidad de abstracción', 'Gestión de equipo', 'Liderazgo']",
#        "['Comunicación escrita', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Pensamiento analítico', 'Capacidad de dar feedback', 'Trabajo en equipo', 'Comunicación verbal', 'Gestión de equipo', 'Resistencia a la frustración', 'Adaptabilidad al cambio']",
#        "['Trabajo en equipo', 'Pensamiento creativo', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Autonomía en el aprendizaje', 'Proactividad']",
#        "['Adaptabilidad al cambio', 'Liderazgo', 'Capacidad de mentorización', 'Aprendizaje Continuo', 'Atención al detalle', 'Pensamiento analítico', 'Capacidad de dar feedback', 'Proactividad', 'Trabajo en equipo']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de autogestión', 'Comunicación escrita', 'Adaptabilidad al cambio', 'Comunicación verbal', 'Capacidad de mentorización', 'Liderazgo', 'Visión crítica', 'Proactividad']",
#        "['Adaptabilidad al cambio', 'Comunicación escrita', 'Aprendizaje Continuo', 'Gestión de equipo', 'Liderazgo', 'Proactividad', 'Visión estratégica']",
#        "['Trabajo en equipo', 'Aprendizaje Continuo', 'Proactividad', 'Pensamiento creativo']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Trabajo en equipo', 'Proactividad', 'Comunicación verbal', 'Atención al detalle', 'Capacidad de autogestión', 'Visión crítica', 'Visión estratégica', 'Capacidad de dar feedback', 'Habilidades de negociación']",
#        "['Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Liderazgo', 'Visión crítica', 'Trabajo en equipo', 'Capacidad de autogestión']",
#        "['Atención al detalle', 'Comunicación escrita', 'Comunicación verbal', 'Capacidad de escucha', 'Aprendizaje Continuo', 'Adaptabilidad al cambio']",
#        "['Adaptabilidad al cambio', 'Capacidad de autogestión', 'Proactividad', 'Atención al detalle', 'Aprendizaje Continuo', 'Comunicación verbal']",
#        "['Capacidad de autogestión', 'Trabajo en equipo', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Proactividad', 'Tolerancia a la incertidumbre']",
#        "['Proactividad', 'Adaptabilidad al cambio', 'Pensamiento creativo', 'Trabajo en equipo', 'Autonomía en el aprendizaje', 'Capacidad de dar feedback', 'Visión crítica', 'Liderazgo', 'Visión estratégica']",
#        "['Capacidad de autogestión', 'Comunicación verbal', 'Atención al detalle', 'Pensamiento analítico', 'Capacidad de dar feedback', 'Resistencia a la frustración', 'Comunicación intercultural', 'Capacidad de mentorización', 'Proactividad', 'Visión estratégica']",
#        "['Trabajo en equipo', 'Proactividad', 'Capacidad de mentorización']",
#        "['Adaptabilidad al cambio', 'Proactividad', 'Aprendizaje Continuo']",
#        "['Trabajo en equipo', 'Adaptabilidad al cambio', 'Aprendizaje Continuo', 'Capacidad de autogestión', 'Capacidad de recibir feedback', 'Capacidad de dar feedback', 'Inteligencia emocional', 'Pensamiento creativo', 'Proactividad', 'Gestión de equipo', 'Liderazgo']",
#        "['Adaptabilidad al cambio', 'Gestión de equipo', 'Visión crítica', 'Pensamiento analítico', 'Inteligencia emocional', 'Visión estratégica']",
#        "['Aprendizaje Continuo', 'Atención al detalle', 'Capacidad de dar feedback', 'Liderazgo', 'Pensamiento analítico']",
#        "['Comunicación verbal', 'Comunicación escrita', 'Trabajo en equipo', 'Pensamiento creativo', 'Aprendizaje Continuo', 'Proactividad', 'Pensamiento analítico', 'Autonomía en el aprendizaje', 'Inteligencia emocional', 'Capacidad de dar feedback']",
#        "['Aprendizaje Continuo', 'Capacidad de abstracción', 'Proactividad', 'Trabajo en equipo', 'Capacidad de escucha', 'Capacidad de recibir feedback', 'Resistencia a la frustración', 'Capacidad de presentación']",
#        "['Adaptabilidad al cambio', 'Autonomía en el aprendizaje', 'Atención al detalle', 'Aprendizaje Continuo', 'Trabajo en equipo']",
#        "['Gestión de equipo', 'Inteligencia emocional', 'Liderazgo', 'Trabajo en equipo', 'Visión estratégica', 'Capacidad de abstracción', 'Comunicación intercultural', 'Pensamiento analítico', 'Visión crítica', 'Habilidades de negociación', 'Capacidad de presentación', 'Atención al detalle']",
#        "['Pensamiento analítico', 'Pensamiento creativo', 'Visión estratégica', 'Resistencia a la frustración', 'Adaptabilidad al cambio', 'Trabajo en equipo', 'Capacidad de dar feedback', 'Atención al detalle']",
#        "['Trabajo en equipo', 'Aprendizaje Continuo', 'Inteligencia emocional', 'Visión estratégica']",
#        "['Aprendizaje Continuo', 'Trabajo en equipo', 'Atención al detalle', 'Autonomía en el aprendizaje', 'Pensamiento analítico']"],
#       dtype=object)

# %% [markdown]
# #### IDIOMAS

# %%
df2["idiomas"].unique()
# Out:
# array(["['Inglés']", "['Español', 'Inglés']", nan, "['Español']",
#        "['Francés', 'Inglés']", "['Alemán', 'Inglés']", "['Francés']"],
#       dtype=object)

# %% [markdown]
# #### DESCRIPCION

# %% [markdown]
# #### BENEFICIOS

# %%
df2["Tecnologías"][1]
# Out:
# "['BigCommerce', 'Salesforce', 'Shopify', 'WooCommerce', 'Magento', 'Prestashop']"

# %%
#funcion para convertir la fecha en formato MM/YYYY
def convertir_fecha(fecha):
    if isinstance(fecha, str) and len(fecha) == 5:
        mes_abr = fecha[:3].lower()
        anio = "20" + fecha[3:]
        mes = meses.get(mes_abr)
        if mes:
            return f"{mes}/{anio}"
    return None

# %%
#aplicar las funciones a las columnas
df2["fecha"] = df2["fecha"].apply(convertir_fecha)

# %%
df2.head()
# Out:
#                                                  url    fecha     salario  \
# 0  https://www.getmanfred.com/ofertas-empleo/7682...  04/2025     €60-70K
# 1  https://www.getmanfred.com/ofertas-empleo/7613...  04/2025     €40-45K
# 2  https://www.getmanfred.com/ofertas-empleo/7512...  03/2025  Hasta €30K
# 3  https://www.getmanfred.com/ofertas-empleo/7441...  03/2025  Hasta €45K
# 4  https://www.getmanfred.com/ofertas-empleo/7305...  03/2025     €70-75K
#
#    remoto localizacion teletrabajo     dia_laborable vacaciones  \
# 0   False    Barcelona         60%  Jornada completa    23 días
# 1    True          NaN        100%  Jornada completa    26 días
# 2   False       Madrid         60%               NaN    23 días
# 3   False       Madrid         70%               NaN    22 días
# 4    True          NaN        100%               NaN    26 días
#
#   jornada_laboral turno_continuo  \
# 0        Flexible            NaN
# 1             NaN        Viernes
# 2             NaN        Viernes
# 3             NaN            NaN
# 4        Flexible            NaN
#
#                                    Otras habilidades                Idiomas  \
# 0  ['Adaptabilidad al cambio', 'Comunicación verb...             ['Inglés']
# 1  ['Comunicación verbal', 'Gestión de equipo', '...                    NaN
# 2  ['Comunicación verbal', 'Capacidad de presenta...  ['Español', 'Inglés']
# 3  ['Trabajo en equipo', 'Adaptabilidad al cambio...             ['Inglés']
# 4                                                NaN             ['Inglés']
#
#                                           Beneficios  \
# 0  ['Clases de Idiomas', 'Seguro de salud', 'Café...
# 1  ['Presupuesto para formación', 'Eventos de for...
# 2  ['Descuento en productos de la empresa', 'Vaca...
# 3  ['Presupuesto para formación', 'Presupuesto pa...
# 4                                                NaN
#
#                                               textos  \
# 0  ¿Cómo lo harás?La transparencia y la claridad ...
# 1  ¿Cómo lo harás?Por supuesto, con una buena com...
# 2  ¿Cómo lo harás?No estarás solo en esta misión....
# 3  ¿Cómo lo harás?Formarás parte de un equipo téc...
# 4  ¿Cómo lo harás?Al más puro estilo scale-up 😉\n...
#
#                                          Tecnologías Guardias
# 0                                                NaN      NaN
# 1  ['BigCommerce', 'Salesforce', 'Shopify', 'WooC...      NaN
# 2     ['Zoho', 'Trello', 'Canva', 'ChatGPT', 'Jira']      NaN
# 3        ['Linux', 'Microsoft', 'Docker', 'Proxmox']      NaN
# 4  ['AWS', 'Docker', 'PostgreSQL', 'Kubernetes', ...      NaN

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   url                100 non-null    object
#  1   fecha              100 non-null    object
#  2   salario            100 non-null    object
#  3   remoto             100 non-null    bool
#  4   localizacion       41 non-null     object
#  5   teletrabajo        95 non-null     object
#  6   dia_laborable      87 non-null     object
#  7   vacaciones         98 non-null     object
#  8   jornada_laboral    63 non-null     object
#  9   turno_continuo     33 non-null     object
#  10  Otras habilidades  97 non-null     object
#  11  Idiomas            50 non-null     object
#  12  Beneficios         90 non-null     object
#  13  textos             100 non-null    object
#  14  Tecnologías        94 non-null     object
#  15  Guardias           3 non-null      object
# dtypes: bool(1), object(15)
# memory usage: 11.9+ KB

# %%
df2.columns
# Out:
# Index(['url', 'fecha', 'salario', 'remoto', 'localizacion', 'teletrabajo',
#        'dia_laborable', 'vacaciones', 'jornada_laboral', 'turno_continuo',
#        'Otras habilidades', 'Idiomas', 'Beneficios', 'textos', 'Tecnologías',
#        'Guardias'],
#       dtype='object')

# %%
df2["localizacion"].value_counts()
# Out:
# localizacion
# Madrid                  23
# Barcelona                7
# A Coruña                 4
# Sevilla                  3
# Zaragoza                 1
# Bergondo or A Coruña     1
# Valencia                 1
# Vigo                     1
# Name: count, dtype: int64

# %%
df2["vacaciones"].value_counts()
# Out:
# vacaciones
# 22 días      31
# 23 días      26
# 26 días      13
# 25 días      12
# 30 días       6
# 24 días       3
# Ilimitado     3
# 21 días       2
# 27 días       1
# 34 días       1
# Name: count, dtype: int64

# %%
df2["dia_laborable"].value_counts()
# Out:
# dia_laborable
# Jornada completa    87
# Name: count, dtype: int64

# %%
df2["fecha"].value_counts()
# Out:
# fecha
# mar25     20
# feb25     11
# ene25     11
# abr25     10
# oct24      9
# jul24      9
# dic24      6
# sept24     6
# jun24      6
# nov24      5
# may24      4
# ago24      3
# Name: count, dtype: int64
