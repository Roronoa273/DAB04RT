# %%
import numpy as np
import pandas as pd

df_Mila = pd.read_csv("C:\\Users\\GoraJ\\Downloads\\aprendiendo python\\PFB\\extracccion\\primera_extraccion_manfred.csv")

# %%
df_Mila.head()
# Out:
#                                                  url  fecha     salario  \
# 0  https://www.getmanfred.com/ofertas-empleo/7682...  abr25     €60-70K
# 1  https://www.getmanfred.com/ofertas-empleo/7613...  abr25     €40-45K
# 2  https://www.getmanfred.com/ofertas-empleo/7512...  mar25  Hasta €30K
# 3  https://www.getmanfred.com/ofertas-empleo/7441...  mar25  Hasta €45K
# 4  https://www.getmanfred.com/ofertas-empleo/7305...  mar25     €70-75K
#
#    remoto localizacion teletrabajo     dia_laborable vacaciones  \
# 0   False    Barcelona         60%  Jornada completa    23 días
# 1    True          NaN        100%  Jornada completa    26 días
# 2   False       Madrid         60%               NaN    23 días
# 3   False       Madrid         70%               NaN    22 días
# 4    True          NaN        100%               NaN    26 días
#
#   jornada_laboral turno_continuo  \
# 0        Flexible            NaN
# 1             NaN        Viernes
# 2             NaN        Viernes
# ...

# %%
df_Anthony = pd.read_excel("C:\\Users\\GoraJ\\Downloads\\aprendiendo python\\PFB\\extracccion\\prueba(con_descripcion).xlsx")

# %%
df_Anthony.head()
# Out:
#                                                 Urls  \
# 0  https://www.tecnoempleo.com/software-engineeri...
# 1  https://www.tecnoempleo.com/front-developer-se...
# 2  https://www.tecnoempleo.com/programador-fullst...
# 3  https://www.tecnoempleo.com/analista-programad...
# 4  https://www.tecnoempleo.com/docente-online-int...
#
#                                    Oferta  \
# 0            Software Engineering Manager
# 1                  Front Developer Senior
# 2                   Programador FullStack
# 3             Analista Programador en PHP
# 4  Docente online Inteligencia Artificial
#
#                                Empresa               Funcion  \
# 0                               Solera  Analista Programador
# 1                         Mytic Innova  Analista Programador
# 2                              Dev&del  Analista Programador
# 3                             Codicert           Programador
# 4  EIP Escuela Internacional Posgrados              Formador
#
# ...

# %%
df_Anthony.columns
# Out:
# Index(['Urls', 'Oferta', 'Empresa', 'Funcion', 'Aptitudes', 'Requisito',
#        'Jornada', 'Contrato', 'Salario', 'Fecha_de_publicacion', 'Ubicacion',
#        'Idiomas', 'Texto'],
#       dtype='object')

# %%
df_Mila.columns
# Out:
# Index(['url', 'fecha', 'salario', 'remoto', 'localizacion', 'teletrabajo',
#        'dia_laborable', 'vacaciones', 'jornada_laboral', 'turno_continuo',
#        'Otras habilidades', 'Idiomas', 'Beneficios', 'textos', 'Tecnologías',
#        'Guardias'],
#       dtype='object')

# %%
list(df_Anthony.columns), list(df_Mila.columns)
# Out:
# (['Urls',
#   'Oferta',
#   'Empresa',
#   'Funcion',
#   'Aptitudes',
#   'Requisito',
#   'Jornada',
#   'Contrato',
#   'Salario',
#   'Fecha_de_publicacion',
#   'Ubicacion',
#   'Idiomas',
#   'Texto'],
#  ['url',
#   'fecha',
#   'salario',
#   'remoto',
#   'localizacion',
#   'teletrabajo',
#   'dia_laborable',
#   'vacaciones',
#   'jornada_laboral',
#   'turno_continuo',
#   'Otras habilidades',
#   'Idiomas',
#   'Beneficios',
#   'textos',
#   'Tecnologías',
#   'Guardias'])

# %% [markdown]
# urls / oferta / empresa / funcion / salario / requisitos / ubicacion / remoto / jornada / contrato / aptitudes / otras habilidades / tenologías / idiomas / vacaciones / beneficios / textos

# %%
df_Anthony2 = pd.read_excel("C:\\Users\\GoraJ\\Downloads\\aprendiendo python\\PFB\\extracccion\\prueba(2).xlsx")

# %%
df_Anthony2.head()
# Out:
#                                                 Urls  \
# 0  https://www.tecnoempleo.com/software-engineeri...
# 1  https://www.tecnoempleo.com/front-developer-se...
# 2  https://www.tecnoempleo.com/programador-fullst...
# 3  https://www.tecnoempleo.com/analista-programad...
# 4  https://www.tecnoempleo.com/docente-online-int...
#
#                                    Oferta  \
# 0            Software Engineering Manager
# 1                  Front Developer Senior
# 2                   Programador FullStack
# 3             Analista Programador en PHP
# 4  Docente online Inteligencia Artificial
#
#                                Empresa               Funcion  \
# 0                               Solera  Analista Programador
# 1                         Mytic Innova  Analista Programador
# 2                              Dev&del  Analista Programador
# 3                             Codicert           Programador
# 4  EIP Escuela Internacional Posgrados              Formador
#
# ...

# %%
import mysql.connector

# %%
db = mysql.connector.connect(host     = "localhost",
                             user     = "root",
                             password = "contraseña1234",
                             database = "ofertas_empleo")

cursor = db.cursor()
